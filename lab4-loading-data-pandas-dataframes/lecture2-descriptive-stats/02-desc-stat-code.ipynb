# %% [markdown]
# # Introduction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
made_up_data = [6, 9, 12, 4, 3, 20, 15, 9] # data1 is a list of integers
type(made_up_data), type(made_up_data[0])
# Out:
# (list, int)

# %%
np.min(made_up_data), np.max(made_up_data)
# Out:
# (3, 20)

# %%
len(made_up_data)
# Out:
# 8

# %%
np.mean(made_up_data) # in python 3.x, same as sum(made_up_data)/len(made_up_data)
# Out:
# 9.75

# %%
np.median(made_up_data)
# Out:
# 9.0

# %% [markdown]
# # Real Data

# %%
# import data from the following dataset
# https://archive.ics.uci.edu/ml/datasets/Adult
#
# "ages" is a list containing ages of people in 1994 Census

data = pd.read_table("http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", sep=",", 
                  names=("age", "type_employer", "fnlwgt", "education", "education_num", "marital", 
                         "occupation", "relationship", "race","sex","capital_gain", "capital_loss", 
                         "hr_per_week","country", "income"))
ages = data["age"].tolist()

# %%
print(len(ages))
print(np.min(ages))
print(np.max(ages))
print(np.mean(ages))
print(np.median(ages))
print(ages[0:100])
# Out:
# 32561
# 17
# 90
# 38.5816467553
# 37.0
# [39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 37, 30, 23, 32, 40, 34, 25, 32, 38, 43, 40, 54, 35, 43, 59, 56, 19, 54, 39, 49, 23, 20, 45, 30, 22, 48, 21, 19, 31, 48, 31, 53, 24, 49, 25, 57, 53, 44, 41, 29, 25, 18, 47, 50, 47, 43, 46, 35, 41, 30, 30, 32, 48, 42, 29, 36, 28, 53, 49, 25, 19, 31, 29, 23, 79, 27, 40, 67, 18, 31, 18, 52, 46, 59, 44, 53, 49, 33, 30, 43, 57, 37, 28, 30, 34, 29, 48, 37, 48, 32]

# %% [markdown]
# # Histograms

# %%
plt.hist(ages,50)
plt.title("1994 Census Histogram")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Quantiles

# %%
np.percentile(ages,25), np.percentile(ages,75)
# Out:
# (28.0, 48.0)

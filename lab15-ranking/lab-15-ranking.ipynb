# %% [markdown]
# # Introduction to Data Science, CS 5963 / Math 3900
# ## Lab 15: Ranking in Practice
#
# We look at rating/ranking college football teams.

# %% [markdown]
# There are a lot of different methods for rating/ranking. Here is a webpage with a comparison:
# [masseyratings.com](http://www.masseyratings.com/cf/compare.htm)
#
# ## College Football Primer
#
# National Collegiate Athletic Association (NCAA) College Football is divided into two subdivisions:
# - Football Bowl Subdivision (FBS), formerly  Division I-A
# - Football Championship Subdivision (FCS), formerly Division I-AA
#
# Our goal will be to rank the 128 teams in the FBS.
#
# The FBS is further divided into 11 conferences, some of which have sub-divisions. The University of Utah is in the South Division of the Pacific 12 (Pac-12) Conference.
#
#       A.  American Athletic Conference
#            i) East Division
#                 Central Florida
#                 Cincinnati
#                 Connecticut
#                 East Carolina
#                 South Florida
#                 Temple
#           ii) West Division
#                 Houston
#                 Memphis
#                 Navy
#                 SMU
#                 Tulane
#                 Tulsa
#       B.  Atlantic Coast Conference
#            i) Atlantic Division
#                 Boston College
#                 Clemson
#                 Florida St
#                 Louisville
#                 North Carolina St
#                 Syracuse
#                 Wake Forest
#          ii) Coastal Division
#                 Duke
#                 Georgia Tech
#                 Miami FL
#                 North Carolina
#                 Pittsburgh
#                 Virginia
#                 Virginia Tech
#       C.  Big 10 Conference
#            i) East Division
#                 Indiana
#                 Maryland
#                 Michigan
#                 Michigan St
#                 Ohio State
#                 Penn State
#                 Rutgers
#          ii) West Division
#                 Illinois
#                 Iowa
#                 Minnesota
#                 Nebraska
#                 Northwestern
#                 Purdue
#                 Wisconsin
#       D.  Big 12 Conference
#             Baylor
#             Iowa St
#             Kansas
#             Kansas St
#             Oklahoma
#             Oklahoma St
#             Texas
#             TCU
#             Texas Tech
#             West Virginia
#       E.  Conference USA
#            i) East Division
#                 Florida Atlantic
#                 Florida Int'l
#                 Marshall
#                 Middle Tennessee St
#                 UNC-Charlotte
#                 Old Dominion
#                 Western Kentucky
#           ii) West Division
#                 Louisiana Tech
#                 North Texas
#                 Rice
#                 Southern Miss
#                 Texas-San Antonio
#                 UTEP
#       F.  Mid-American Conference
#            i) East Division
#                 Akron
#                 Bowling Green
#                 Buffalo
#                 Kent St
#                 Miami OH
#                 Ohio U.
#           ii) West Division
#                 Ball St
#                 Central Michigan
#                 Eastern Michigan
#                 Northern Illinois
#                 Toledo
#                 Western Michigan
#       G.  Mountain West Conference
#            i) Mountain Division
#                 Air Force
#                 Boise St
#                 Colorado St
#                 New Mexico
#                 Utah St
#                 Wyoming
#           ii) West Division
#                 Fresno St
#                 Hawai`i
#                 Nevada
#                 San Diego St
#                 San José St
#                 UNLV
#       H.  Pacific 12 Conference
#            i) North Division
#                 California
#                 Oregon
#                 Oregon St
#                 Stanford
#                 Washington
#                 Washington St
#           ii) South Division
#                 Arizona
#                 Arizona St
#                 Colorado
#                 Southern Cal
#                 UCLA
#                 Utah
#       I.  Southeastern Conference
#            i) Eastern Division
#                 Florida
#                 Georgia
#                 Kentucky
#                 Missouri
#                 South Carolina
#                 Tennessee
#                 Vanderbilt
#           ii) Western Division
#                 Alabama
#                 Arkansas
#                 Auburn
#                 LSU
#                 Mississippi
#                 Mississippi St
#                 Texas A&M
#       J.  Sun Belt Conference
#             Appalachian St
#             Arkansas St
#             Georgia Southern
#             Georgia St
#             Idaho
#             Louisiana-Lafayette
#             Louisiana-Monroe
#             New Mexico St
#             South Alabama
#             Texas St-San Marcos
#             Troy
#       K.  Division I FBS Independents
#             Army
#             Brigham Young
#             Massachusetts
#             Notre Dame
#
# More conference information available [here](http://prwolfe.bol.ucla.edu/cfootball/conferences.htm).
#
# ## Download data
#
# We download the 2016 College Football game results from
# [this website](http://masseyratings.com/scores.php?s=286577&sub=286577&all=1). So far, there have been 4206 games.

# %%
# imports and setup
import numpy as np
import pandas as pd
import networkx as nx

from bs4 import BeautifulSoup
import urllib.request
from io import StringIO

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('ggplot')

# %% [markdown]
# ### First get a list of team names

# %%
url = "http://masseyratings.com/scores.php?s=286577&sub=286577&all=1&mode=3&format=2"
with urllib.request.urlopen(url) as response:
   html = response.read()
soup = BeautifulSoup(html, 'html.parser')

print(soup)
# Out:
#    1, Abilene_Chr
#    2, Acadia
#    3, Adams_St
#    4, Adrian
#    5, Air_Force
#    6, Akron
#    7, Alabama
#    8, Alabama_A&amp;M;
#    9, Alabama_St
#   10, Albany_GA
#   11, Albany_NY
#   12, Alberta
#   13, Albion
#   14, Albright
#   15, Alcorn_St
#   16, Ald-Broaddus
#   17, Alfred
#   18, Alfred_St
#   19, Allan_Hancock
#   20, Allegheny
#   21, Alma
#   22, American_Intl
#   23, American_River
#   24, Amherst
#   25, Anderson_IN
#   26, Angelo_St
#   27, Anna_Maria
#   28, Antelope_Val_CC
#   29, Appalachian_St
#   30, Apprentice
#   31, Arizona
#   32, Arizona_Chr
#   33, Arizona_St
#   34, Ark_Baptist
#   35, Ark_Monticello
#   36, Ark_Pine_Bluff
#   37, Arkansas
#   38, Arkansas_St
#   39, Arkansas_Tech
#   40, Army
#   41, ASA
#   42, ASA_Miami
#   43, Ashland
#   44, Assumption
#   45, Auburn
#   46, Augsburg
#   47, Augustana_IL
#   48, Augustana_SD
#   49, Aurora
#   50, Austin_Col
#   51, Austin_Peay
#   52, Ave_Maria
#   53, Averett
#   54, Avila
#   55, AZ_Western
#   56, Azusa_Pacific
#   57, Bacone
#   58, Baker_KS
#   59, Bakersfield_Col
#   60, Baldwin-Wallace
#   61, Ball_St
#   62, Bates
#   63, Baylor
#   64, Becker
#   65, Belhaven_MS
#   66, Beloit
#   67, Bemidji_St
#   68, Benedict
#   69, Benedictine_IL
#   70, Benedictine_KS
#   71, Bentley
#   72, Berry
#   73, Bethany_KS
#   74, Bethany_WV
#   75, Bethel_KS
#   76, Bethel_MN
#   77, Bethel_TN
#   78, Bethune-Cookman
#   79, Birmingham_So
#   80, Bishop's
#   81, Black_Hills_St
#   82, Blinn
#   83, Bloomsburg
#   84, Bluefield_VA
#   85, Bluffton
#   86, Boise_St
#   87, Boston_College
#   88, Bowdoin
#   89, Bowie_St
#   90, Bowling_Green
#   91, Brevard
#   92, Briar_Cliff
#   93, Bridgewater_MA
#   94, Bridgewater_VA
#   95, Brit_Columbia
#   96, Brockport_St
#   97, Brown
#   98, Bryant
#   99, Bucknell
#  100, Buena_Vista
#  101, Buffalo
#  102, Buffalo_St
#  103, Butler
#  104, Butler_Co-KS
#  105, Butte_Col
#  106, BYU
#  107, C_Michigan
#  108, C_Missouri
#  109, C_Oklahoma
#  110, C_Washington
#  111, Cabrillo
#  112, Cal_Lutheran
#  113, Cal_Poly_SLO
#  114, Calgary
#  115, California
#  116, California_PA
#  117, Campbell
#  118, Campbellsville
#  119, Capital
#  120, Carleton_MN
#  121, Carleton_ON
#  122, Carnegie_Mellon
#  123, Carroll_MT
#  124, Carroll_WI
#  125, Carson-Newman
#  126, Carthage
#  127, Case_Western
#  128, Castleton
#  129, Catawba
#  130, Catholic
#  131, Cent_Arkansas
#  132, Cent_Methodist
#  133, Central_Conn
#  134, Central_IA
#  135, Central_Lakes
#  136, Central_St_OH
#  137, Centre
#  138, Cerritos_Col
#  139, Chabot
#  140, Chadron_St
#  141, Chaffey
#  142, Chapman
#  143, Charleston_So
#  144, Charleston_WV
#  145, Charlotte
#  146, Chattanooga
#  147, Cheyney_St
#  148, Chicago
#  149, Chowan
#  150, Chris_Newport
#  151, Cincinnati
#  152, Cincinnati_Chr
#  153, Cisco_JC
#  154, Citadel
#  155, Citrus_Col
#  156, City_Col_San_Fran
#  157, Claremont_M.S.
#  158, Clarion
#  159, Clark_Atlanta
#  160, Clemson
#  161, Coahoma_CC
#  162, Coast_Guard
#  163, Coastal_Car
#  164, Coe
#  165, Coffeyville_CC
#  166, Col_of_Dupage
#  167, Col_of_Idaho
#  168, Col_of_the_Canyons
#  169, Col_of_the_Desert
#  170, Col_of_the_Redwoods
#  171, Col_of_the_Sequoias
#  172, Col_San_Mateo
#  173, Col_Sherbrooke
#  174, Colby
#  175, Colgate
#  176, College_of_NJ
#  177, Colorado
#  178, Colorado_Mines
#  179, Colorado_St
#  180, Columbia
#  181, Compton_CC
#  182, Concord
#  183, Concordia_IL
#  184, Concordia_Mhd
#  185, Concordia_MI
#  186, Concordia_NE
#  187, Concordia_QC
#  188, Concordia_SP
#  189, Concordia_WI
#  190, Connecticut
#  191, Contra_Costa
#  192, Copiah-Lincoln
#  193, Cornell
#  194, Cornell_IA
#  195, Cortland_St
#  196, Crown_MN
#  197, CS_Sacramento
#  198, CSU-Pueblo
#  199, Culver-Stockton
#  200, Cumberland_TN
#  201, Cumberlands_KY
#  202, Curry
#  203, CW_Post
#  204, Dakota_St
#  205, Dakota_Wesleyan
#  206, Dakota-Bottineau
#  207, Dartmouth
#  208, Davenport
#  209, Davidson
#  210, Dayton
#  211, De_Anza_Col
#  212, Dean
#  213, Defiance
#  214, Delaware
#  215, Delaware_St
#  216, Delaware_Val
#  217, Delta_St
#  218, Denison
#  219, DePauw
#  220, Diablo_Val
#  221, Dickinson
#  222, Dickinson_St_ND
#  223, Dixie_St
#  224, Doane
#  225, Dodge_City_CC
#  226, Dordt
#  227, Drake
#  228, Dubuque
#  229, Duke
#  230, Duquesne
#  231, E_Illinois
#  232, E_Kentucky
#  233, E_Michigan
#  234, E_Mississippi_CC
#  235, E_New_Mexico
#  236, E_Stroudsburg
#  237, E_Texas_Bap
#  238, E_Washington
#  239, Earlham
#  240, East_Carolina
#  241, East_Central_CC
#  242, East_Central_OK
#  243, East_LA_Col
#  244, Eastern_Arizona
#  245, Eastern_Oregon
#  246, Edinboro
#  247, Edward_Waters
#  248, El_Camino_Col
#  249, Eliz._City_St
#  250, Ellsworth_CC
#  251, Elmhurst
#  252, Elon
#  253, Emory_&amp;_Henry
#  254, Emporia_St
#  255, Endicott
#  256, Erie_CC
#  257, ETSU
#  258, Eureka
#  259, Evangel
#  260, Fairmont_St
#  261, Faulkner
#  262, Fayetteville_St
#  263, FDU_Madison
#  264, Feather_River
#  265, Ferris_St
#  266, Ferrum
#  267, Findlay
#  268, Finlandia
#  269, Fitchburg_St
#  270, FL_Atlantic
#  271, Florida
#  272, Florida_A&amp;M;
#  273, Florida_Intl
#  274, Florida_St
#  275, Florida_Tech
#  276, Fond_du_Lac_T&amp;CC;
#  277, Foothill_Col
#  278, Fordham
#  279, Fort_Hays_St
#  280, Fort_Scott_CC
#  281, Fort_Valley_St
#  282, Framingham_St
#  283, Frank_&amp;_Marsh
#  284, Franklin_IN
#  285, Fresno_City_Col
#  286, Fresno_St
#  287, Friends
#  288, Frostburg_St
#  289, Ft_Lewis
#  290, Fullerton_Col
#  291, Furman
#  292, Ga_Southern
#  293, Gallaudet
#  294, Gannon
#  295, Garden_City_CC
#  296, Gardner_Webb
#  297, Gavilan
#  298, Geneva
#  299, George_Fox
#  300, Georgetown
#  301, Georgetown_KY
#  302, Georgia
#  303, Georgia_Mil
#  304, Georgia_St
#  305, Georgia_Tech
#  306, Gettysburg
#  307, Glendale_AZ
#  308, Glendale_CA
#  309, Glenville_St
#  310, Golden_West
#  311, Graceland
#  312, Grambling
#  313, Grand_Valley_St
#  314, Grandview
#  315, Greensboro
#  316, Greenville
#  317, Grinnell
#  318, Grossmont
#  319, Grove_City
#  320, Guelph
#  321, Guilford
#  322, Gust_Adolphus
#  323, Hamilton
#  324, Hamline
#  325, Hampden-Sydney
#  326, Hampton
#  327, Hanover
#  328, Hardin-Simmons
#  329, Harding
#  330, Hartnell
#  331, Hartwick
#  332, Harvard
#  333, Hastings
#  334, Hawaii
#  335, Heidelberg
#  336, Henderson_St
#  337, Hendrix
#  338, Highland_CC_KS
#  339, Hillsdale
#  340, Hinds_CC
#  341, Hiram
#  342, Hobart_&amp;_Smith
#  343, Hocking
#  344, Holmes_CC
#  345, Holy_Cross
#  346, Hope
#  347, Houston
#  348, Houston_Bap
#  349, Howard
#  350, Howard_Payne
#  351, Hudson_Val
#  352, Humboldt_St
#  353, Huntingdon
#  354, Husson
#  355, Hutchinson_CC
#  356, Idaho
#  357, Idaho_St
#  358, IL_Wesleyan
#  359, Illinois
#  360, Illinois_Col
#  361, Illinois_St
#  362, Incarnate_Word
#  363, Independence_CC
#  364, Indiana
#  365, Indiana_PA
#  366, Indiana_St
#  367, Indianapolis
#  368, Iowa
#  369, Iowa_Cent
#  370, Iowa_St
#  371, Iowa_Wesleyan
#  372, Iowa_Western_CC
#  373, Itasca_CC
#  374, Itawamba_CC
#  375, Ithaca
#  376, Jackson_St
#  377, Jacksonville
#  378, Jacksonville_St
#  379, James_Madison
#  380, Jamestown
#  381, JC_Smith
#  382, John_Carroll
#  383, Johns_Hopkins
#  384, Jones_Co_CC
#  385, Juniata
#  386, Kalamazoo
#  387, Kansas
#  388, Kansas_St
#  389, Kean
#  390, Kennesaw
#  391, Kent
#  392, Kentucky
#  393, Kentucky_Chr
#  394, Kentucky_St
#  395, Kenyon
#  396, Kilgore
#  397, King's_PA
#  398, Knox
#  399, KS_Wesleyan
#  400, Kutztown
#  401, KY_Wesleyan
#  402, LA_Harbor
#  403, LA_Pierce
#  404, LA_Southwest
#  405, LA_Valley_Col
#  406, La_Verne
#  407, Lackawanna
#  408, Lafayette
#  409, LaGrange
#  410, Lake_Erie
#  411, Lake_Forest
#  412, Lakeland
#  413, Lamar
#  414, Lane
#  415, Laney
#  416, Langston
#  417, Laurier
#  418, Laval
#  419, Lawrence
#  420, Lebanon_Val
#  421, Lehigh
#  422, Lenoir_Rhyne
#  423, Lewis_&amp;_Clark
#  424, Liberty
#  425, Limestone
#  426, Lincoln_MO
#  427, Lincoln_PA
#  428, Lindenwood
#  429, Lindenwood-Belleville
#  430, Lindsey_Wilson
#  431, Linfield
#  432, Livingstone
#  433, Lock_Haven
#  434, Long_Beach_City_Col
#  435, Loras
#  436, Los_Medanos
#  437, Louisburg
#  438, Louisiana_Col
#  439, Louisiana_Tech
#  440, Louisville
#  441, LSU
#  442, Luther_IA
#  443, Luther_MN
#  444, Lycoming
#  445, Lyon
#  446, M_Hardin-Baylor
#  447, MA_Dartmouth
#  448, MA_Maritime
#  449, Macalester
#  450, MacMurray
#  451, Maine
#  452, Malone
#  453, Manchester
#  454, Manitoba
#  455, Maranatha_Bap
#  456, Marian_IN
#  457, Marietta
#  458, Marist
#  459, Mars_Hill
#  460, Marshall
#  461, Mary_ND
#  462, Maryland
#  463, Maryville_TN
#  464, Massachusetts
#  465, Mayville_St
#  466, McDaniel_Col
#  467, McGill
#  468, McKendree
#  469, McMaster
#  470, McMurry
#  471, McNeese_St
#  472, McPherson
#  473, ME_Maritime
#  474, Memphis
#  475, Mendocino
#  476, Merced_Col
#  477, Mercer
#  478, Merchant_Marine
#  479, Mercyhurst
#  480, Merrimack
#  481, Mesa_CC
#  482, Mesa_St
#  483, Mesabi_Range
#  484, Methodist
#  485, Miami_FL
#  486, Miami_OH
#  487, Michigan
#  488, Michigan_St
#  489, Michigan_Tech
#  490, Mid_Am_Nazarene
#  491, Middlebury
#  492, Midland_NE
#  493, Midwest_TX_St
#  494, Miles
#  495, Millersville
#  496, Millikin
#  497, Millsaps
#  498, Minnesota
#  499, Minot_St
#  500, Misericordia
#  501, Mississippi
#  502, Mississippi_Col
#  503, Mississippi_St
#  504, Missouri
#  505, Missouri_S&amp;T;
#  506, Missouri_St
#  507, Missouri_Val
#  508, MIT
#  509, MN_Crookston
#  510, MN_Duluth
#  511, MN_Mankato
#  512, MN_Morris
#  513, MN_St_CTC
#  514, MN_West_C&amp;T;
#  515, MO_Baptist
#  516, MO_Southern
#  517, MO_Western
#  518, Modesto_JC
#  519, Monmouth_IL
#  520, Monmouth_NJ
#  521, Monroe
#  522, Montana
#  523, Montana_St
#  524, Montclair_St
#  525, Monterey_Peninsula
#  526, Montreal
#  527, Moorhead_St
#  528, Moorpark
#  529, Moravian
#  530, Morehead_St
#  531, Morehouse
#  532, Morgan_St
#  533, Morningside
#  534, Morrisville_St
#  535, Morthland
#  536, MS_Delta
#  537, MS_Gulf_Coast
#  538, MS_Valley_St
#  539, Mt_Allison
#  540, Mt_Ida
#  541, Mt_San_Antonio
#  542, Mt_San_Jacinto
#  543, Mt_St_Joseph
#  544, MT_St_Northern
#  545, MT_Tech
#  546, Mt_Union
#  547, MT_Western
#  548, MTSU
#  549, Muhlenberg
#  550, Murray_St
#  551, Muskingum
#  552, N_Central_IL
#  553, N_Colorado
#  554, N_Dakota_St
#  555, N_Illinois
#  556, N_Michigan
#  557, Nassau_CC
#  558, Navarro
#  559, Navy
#  560, NC_A&amp;T;
#  561, NC_Central
#  562, NC_Pembroke
#  563, NC_State
#  564, NC_Wesleyan
#  565, ND_St_Science
#  566, NE_Kearney
#  567, NE_MS_CC
#  568, NE_OK_A&amp;M;
#  569, NE_Oklahoma
#  570, NE_Wesleyan
#  571, Nebraska
#  572, Nevada
#  573, New_Hampshire
#  574, New_Haven
#  575, New_Mexico
#  576, New_Mexico_St
#  577, Newberry
#  578, Nicholls_St
#  579, Nichols
#  580, NM_Highlands
#  581, NM_Military
#  582, Norfolk_St
#  583, North_Alabama
#  584, North_Carolina
#  585, North_Dakota
#  586, North_Greenville
#  587, North_Park
#  588, North_Texas
#  589, Northern_Arizona
#  590, Northern_Iowa
#  591, Northern_St_SD
#  592, Northland_CTC
#  593, Northwestern
#  594, Northwestern_IA
#  595, Northwestern_LA
#  596, Northwestern_MN
#  597, Northwood_MI
#  598, Norwich
#  599, Notre_Dame
#  600, Notre_Dame_OH
#  601, NW_Mississippi
#  602, NW_Missouri
#  603, NW_Oklahoma_St
#  604, NY_Maritime
#  605, Oberlin
#  606, Occidental
#  607, OH_Dominican
#  608, Ohio
#  609, Ohio_Northern
#  610, Ohio_St
#  611, Ohio_Wesleyan
#  612, OK_Baptist
#  613, Oklahoma
#  614, Oklahoma_St
#  615, Old_Dominion
#  616, Olivet_MI
#  617, Olivet_Naz
#  618, Orange_Coast
#  619, Oregon
#  620, Oregon_St
#  621, Ottawa_KS
#  622, Ottawa_ON
#  623, Otterbein
#  624, Ouachita
#  625, Pac_Lutheran
#  626, Pace
#  627, Pacific_OR
#  628, Palomar_Col
#  629, Panhandle_St
#  630, Pasadena_City_Col
#  631, Pearl_River_CC
#  632, Penn
#  633, Penn_St
#  634, Permian_Basin
#  635, Peru_St
#  636, Phoenix_Col
#  637, Pikeville
#  638, Pima_CC
#  639, Pittsburg_St
#  640, Pittsburgh
#  641, Plymouth_St
#  642, Point
#  643, Pomona_Pitzer
#  644, Portland_St
#  645, Prairie_View
#  646, Presbyterian
#  647, Presentation
#  648, Princeton
#  649, Puget_Sound
#  650, Purdue
#  651, Queen's_ON
#  652, Quincy
#  653, R_Morris_Chi
#  654, Randolph_Macon
#  655, Redlands
#  656, Reedley
#  657, Regina
#  658, Reinhardt
#  659, Rensselaer
#  660, Rhode_Island
#  661, Rhodes
#  662, Rice
#  663, Richmond
#  664, Ridgewater
#  665, Ripon
#  666, Riverside_CC
#  667, Robert_Morris
#  668, Rochester_C&amp;T;
#  669, Rochester_NY
#  670, Rockford
#  671, Rocky_Mtn
#  672, Rose-Hulman
#  673, Rowan
#  674, Rutgers
#  675, S_Arkansas
#  676, S_Carolina_St
#  677, S_Connecticut
#  678, S_Dakota_St
#  679, S_Dakota_Tech
#  680, S_Illinois
#  681, S_Virginia
#  682, Sacramento_City
#  683, Sacred_Heart
#  684, Saddleback
#  685, Saginaw_Val
#  686, Salisbury_St
#  687, Salve_Regina
#  688, Sam_Houston_St
#  689, Samford
#  690, San_Bernardino_Val
#  691, San_Diego
#  692, San_Diego_Mesa
#  693, San_Diego_St
#  694, San_Joaquin_Delta
#  695, San_Jose_City_Col
#  696, San_Jose_St
#  697, Santa_Ana_Col
#  698, Santa_Barbara_City
#  699, Santa_Monica_Col
#  700, Santa_Rosa_JC
#  701, Saskatchewan
#  702, Savannah_St
#  703, Scottsdale_CC
#  704, SE_Louisiana
#  705, SE_Missouri_St
#  706, SE_Oklahoma
#  707, Seton_Hill
#  708, Sewanee
#  709, SF_Austin
#  710, Shasta_Col
#  711, Shaw_NC
#  712, Shenandoah
#  713, Shepherd
#  714, Shippensburg
#  715, Shorter
#  716, Siena_Hts
#  717, Sierra_Col
#  718, Simon_Fraser
#  719, Simpson_IA
#  720, Sioux_Falls
#  721, Siskiyous
#  722, Slippery_Rock
#  723, SMU
#  724, Snow_Col
#  725, South_Alabama
#  726, South_Carolina
#  727, South_Dakota
#  728, South_Florida
#  729, Southeastern_FL
#  730, Southern_Miss
#  731, Southern_Nazarene
#  732, Southern_Oregon
#  733, Southern_Univ
#  734, Southern_Utah
#  735, Southwestern_CA
#  736, Southwestern_KS
#  737, Springfield
#  738, St_Ambrose
#  739, St_Anselm
#  740, St_Augustine's
#  741, St_Cloud
#  742, St_Fran_Xavier
#  743, St_Francis_IL
#  744, St_Francis_IN
#  745, St_Francis_PA
#  746, St_John_Fisher
#  747, St_John's_MN
#  748, St_Joseph's_IN
#  749, St_Lawrence
#  750, St_Mary_KS
#  751, St_Mary's_NS
#  752, St_Norbert
#  753, St_Olaf
#  754, St_Scholastica
#  755, St_Thomas_MN
#  756, St_Vincent
#  757, St_Xavier_IL
#  758, Stanford
#  759, Sterling
#  760, Stetson
#  761, Stevenson
#  762, Stonehill
#  763, Stony_Brook
#  764, Sul_Ross
#  765, Susquehanna
#  766, SW_Assemb_God
#  767, SW_Baptist
#  768, SW_Minnesota
#  769, SW_Mississippi
#  770, SW_Oklahoma
#  771, SW_Univ_TX
#  772, Syracuse
#  773, Tabor
#  774, Tarleton_St
#  775, Taylor_IN
#  776, TCU
#  777, Temple
#  778, Tennessee
#  779, Tennessee_St
#  780, Tennessee_Tech
#  781, Texas
#  782, Texas_A&amp;M;
#  783, Texas_Col
#  784, Texas_St
#  785, Texas_Tech
#  786, Thiel
#  787, Thomas_More
#  788, Tiffin
#  789, TN_Martin
#  790, Toledo
#  791, Toronto
#  792, Towson
#  793, Trine
#  794, Trinity_Bib
#  795, Trinity_CT
#  796, Trinity_IL
#  797, Trinity_TX
#  798, Trinity_Valley_CC
#  799, Troy
#  800, Truman_St
#  801, Tufts
#  802, Tulane
#  803, Tulsa
#  804, Tusculum
#  805, Tuskegee
#  806, TX_A&amp;M;_Commerce
#  807, TX_A&amp;M;_K'ville
#  808, TX_Lutheran
#  809, TX_Southern
#  810, Tyler_JC
#  811, UC_Davis
#  812, UCF
#  813, UCLA
#  814, ULL
#  815, ULM
#  816, Union_KY
#  817, Union_NY
#  818, UNLV
#  819, Upper_Iowa
#  820, Urbana
#  821, Ursinus
#  822, USC
#  823, UT_San_Antonio
#  824, Utah
#  825, Utah_St
#  826, UTEP
#  827, Utica
#  828, UVA-Wise
#  829, VA-Lynchburg
#  830, Valdosta_St
#  831, Valley_City_St
#  832, Valparaiso
#  833, Vanderbilt
#  834, Ventura_Col
#  835, Vermilion_CC
#  836, Victor_Valley
#  837, Villanova
#  838, Virginia
#  839, Virginia_St
#  840, Virginia_Tech
#  841, Virginia_Union
#  842, VMI
#  843, W_Carolina
#  844, W_Connecticut
#  845, W_Illinois
#  846, W_Michigan
#  847, W_New_England
#  848, W_New_Mexico
#  849, W_Oregon
#  850, W_Salem_St
#  851, W_Texas_A&amp;M;
#  852, Wabash
#  853, Wagner
#  854, Wake_Forest
#  855, Waldorf
#  856, Walsh
#  857, Warner
#  858, Wartburg
#  859, Wash_&amp;_Jeff
#  860, Wash_&amp;_Lee
#  861, Washburn
#  862, Washington
#  863, Washington_MO
#  864, Washington_St
#  865, Waterloo
#  866, Wayland
#  867, Wayne_St_MI
#  868, Wayne_St_NE
#  869, Waynesburg
#  870, Webber
#  871, Weber_St
#  872, Wesley_DE
#  873, Wesleyan_CT
#  874, West_Alabama
#  875, West_Chester
#  876, West_Florida
#  877, West_Georgia
#  878, West_Hills
#  879, West_LA_Col
#  880, West_Liberty
#  881, West_Virginia
#  882, Western_ON
#  883, Western_St_CO
#  884, Westfield_St
#  885, Westminster_MO
#  886, Westminster_PA
#  887, Wheaton_IL
#  888, Whittier
#  889, Whitworth
#  890, WI_Eau_Claire
#  891, WI_LaCrosse
#  892, WI_Lutheran
#  893, WI_Oshkosh
#  894, WI_Platteville
#  895, WI_River_Falls
#  896, WI_Stevens_Pt
#  897, WI_Stout
#  898, WI_Whitewater
#  899, Widener
#  900, Wilkes
#  901, Willamette
#  902, William_&amp;_Mary
#  903, William_Penn
#  904, Williams
#  905, Wilmington_OH
#  906, Windsor
#  907, Wingate
#  908, Winona_St
#  909, Wisconsin
#  910, Wittenberg
#  911, WKU
#  912, Wm_Jewell
#  913, Wm_Paterson
#  914, Wofford
#  915, Wooster
#  916, Worcester_St
#  917, Worcester_Tech
#  918, WV_State
#  919, WV_Wesleyan
#  920, Wyoming
#  921, Yale
#  922, York_ON
#  923, Youngstown_St
#  924, Yuba

# %% [markdown]
# ### Exercise: load the team names into a Pandas dataframe
# Call the Pandas dataframe 'teams' and name the column with the team names 'team'
#
# **Hint**: you might use the BeautifulSoup command *get_text()* and the string command split()

# %%
# your code here
list_names = soup.get_text().split()([1::2])
num_teams = teams.shape[0]
print(num_teams)

print(teams)

# %%
# where is Utah in the Pandas series teams? 
teams[teams['team']=='Utah'].index.tolist()

# %%
teams.loc[823]

# %% [markdown]
# ### Get the game results

# %%
url = "http://masseyratings.com/scores.php?s=286577&sub=286577&all=1&mode=3&format=1"
with urllib.request.urlopen(url) as response:
   html = response.read()
soup = BeautifulSoup(html, 'html.parser')

soup

# %%
soup_text = soup.get_text()
df = pd.read_csv(StringIO(soup_text),names=['id','date','team1','homefield1','score1','team2','homefield2','score2'])

num_games = df.shape[0]
print(num_games)

df.head()

# %% [markdown]
# ### Clean the data

# %%
# add a new column with team names
df.drop(['homefield1','homefield2'],inplace=True,axis=1)
df.insert(3, 'team_name1', df['team1'].map(lambda x: teams['team'][x-1]))
df.insert(6, 'team_name2', df['team2'].map(lambda x: teams['team'][x-1]))
df.head()

# %% [markdown]
# ## Consider only Pac 12 teams

# %%
P12 = ['California', 'Oregon', 'Oregon_St', 'Stanford', 'Washington', 'Washington_St', 
    'Arizona', 'Arizona_St', 'Colorado', 'USC', 'UCLA', 'Utah'] 
num_P12_teams = len(P12)

# get PAC12 teams from teams
P12_ind = teams[teams['team'].isin(P12)].index.tolist()  
P12_teams = teams.loc[P12_ind]

# assign a new ordering for teams
P12_teams['P12_ind'] = np.arange(num_P12_teams)
P12_teams['global_ind'] = P12_teams.index
P12_teams.set_index('P12_ind',inplace=True)

P12_teams

# %% [markdown]
# ### Exercise: Get the PAC12 games
# Make a new dataframe called *P12_df*, with game results from the dataframe *df* in which the teams were both in the PAC12.

# %%
# your code here
P12_home= df[(df['team name1'].isin(P12)) & (df['team name2'].isin(P12))]

num_P12_games = P12_df.shape[0]
print(num_P12_games)
print(P12_df)

# %% [markdown]
# ## Use the Least Squares method to construct a rating
# See Lecture 16.
#
# We first construct the pairwise comparisons, $y_{i,j}$ defined by
# $$
# y_{i,j} = \frac{\text{points team $j$ scored - points team $i$ scored}}{\text{total points in game}}.
# $$

# %%
P12_df['y'] = (P12_df['score1'] - P12_df['score2']) / (P12_df['score1'] + P12_df['score2'])
y = P12_df['y'].tolist()
P12_df

# %% [markdown]
# Construct the arc-vertex incidence matrix
# $$
# B_{k,j} = \begin{cases}
# 1 & j = \textrm{head}(k) \\
# -1 & j = \textrm{tail}(k) \\
# 0 & \textrm{otherwise}.
# \end{cases}
# $$
# This just keeps track of which teams played in each game.

# %%
# first we need to reorder the teams in the PAC12 ordering

print(P12_teams['global_ind'].tolist())

glob_P12_dict = {j:i for i,j in enumerate(P12_teams['global_ind'].tolist())}
print(glob_P12_dict)

# %%
# construct B

B = np.zeros((num_P12_games, num_P12_teams))

for ii,g in enumerate(P12_df.index):
    team1_global_ind = P12_df['team1'][g]
    team1_P12_ind = glob_P12_dict[team1_global_ind-1]    
    B[ii,team1_P12_ind] = 1

    team2_global_ind = P12_df['team2'][g]
    team2_P12_ind = glob_P12_dict[team2_global_ind-1]    
    B[ii,team2_P12_ind] = -1

# %%
# now we have enough information just to print the  game results 
for i,sc in enumerate(y):
    head = np.where(B[i,:]==1)[0][0]
    tail = np.where(B[i,:]==-1)[0][0]
    print(P12_teams['team'][head] + ' vs. ' + P12_teams['team'][tail] + ': ' +str(sc))

# %% [markdown]
# We now use the *lstsq* function in the np.linalg library to find the least squares rating, solving the least squares problem,
# $$
# \min_{\phi} \ \| B \phi - y \|^2.
# $$

# %%
phi = np.linalg.lstsq(B,y,rcond=.1)[0]
print(phi)

# %%
P12_teams['rating'] = phi
print(P12_teams)

# %% [markdown]
# ## Sort the ratings to generate a ranking

# %%
P12_rankings = P12_teams.sort_values('rating', axis=0, ascending=False)
P12_rankings['ranking'] = np.arange(1,num_P12_teams+1)
P12_rankings.set_index('ranking',inplace=True)
P12_rankings.drop('global_ind',axis=1,inplace=True)
print(P12_rankings)

# %% [markdown]
# ### Exercise: discuss the results
# Compare against the PAC 12 rankings [here](https://pac-12.com/football/standings).

# %% [markdown]
# ## Visualize the schedule

# %%
# make graph
Lap = np.dot(np.transpose(B),B)
adj = -Lap + np.diag(np.diag(Lap))
game_graph = nx.from_numpy_matrix(adj)

# Calculate the layout positions first
pos = nx.spring_layout(game_graph)

# labeling needs a dictionary
label_dict = {i:j for i,j in enumerate(P12_teams['team'].tolist())}

# draw graph
nx.draw_networkx(game_graph, pos=pos, node_size=3000, labels = label_dict, node_shape='s')
plt.show()

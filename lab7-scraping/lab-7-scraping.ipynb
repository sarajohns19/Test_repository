# %% [markdown]
# # Introduction to Data Science - Lab 7 - Scraping
# *CS 5963 / MATH 3900, University of Utah, http://datasciencecourse.net/*
#
# In this lab we will explore how we can extract data from a web-age using automatic scraping and crawling with [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# First, we'll talk a bit about HTML though.
#
# ## HTML and the DOM
#
# In this lab we will scrape web-pages that are (partially) written in HTML and represented in the DOM. DOM stands for  Document Object Model, while HTML stands for “HyperText Markup Language”. 25 years ago, that used to be a meaningful description of what HTML actually did: it has links (hypertext), and it is a markup language. The latest version of HTML, however, the HTML5 standard, does much, much more: graphics, audio, video, etc. So it is easier to think of HTML as “whatever it is that web browsers know how to interpret”, and just not think about the actual term.
#
# ### Elements
#
# The important thing about HTML is that the markup is represented by elements. An HTML element is a portion of the content that is surrounded by a pair of tags of the same name. Like this:
#
# ```html
# <strong>This is an HTML element.</strong>
# ```
#
# In this element, strong is the name of the tag; the open tag is `<strong>`, and the matching closing tag is `</strong>`. The way you should interpret this is that the text “This is an HTML element” should be “strong”, i.e., typically this will be bold text.
#
# HTML elements can and commonly do nest:
#
# ```html
# <strong>This is strong, and <u>this is underlined and strong.</u></strong>
# ```
#
# In addition to the names, opening tags can contain extra information about the element. These are called attributes:
#
# ```html
# <a href='http://www.google.com'>A link to Google's main page</a>
# ```
#
# In this case, we’re using the `a` element which stood for “anchor”, but now is almost universally used as a “link”. The attribute `href` means “HTML reference”, which actually makes sense for a change. The meaning given to each attribute changes from element to element.
#
# Important attributes for our purposes are `id` and `class`. The id attribute gives the attribute a unique identifier, which can then be used to access the element programmatically. Think of it as making the element accessible via a global variable.  The class is conceptually similar but is intendent to be applied to a whole "class" of elements.
#
# HTML pages require some boilerplate. Here is a minimal page:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title></title>
# </head>
# <body>
# Hello World! What's up?
# </body>
# </html>
# ```
#
# The `<head>` contains meta-information such as the titel of the site, the `<body>` contains the actual data.
#
# ### Hierarchy
#
# Data in HTML is always structured hirearchically:
#
# ```html
# <body>
#   <article>
#     <span class="date">Published: 2016-08-25</span>
#     <span class="author">Led Zeppelin</span>
#     <h1>Ramble On</h1>
#     <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     <div>
#   </article>
#   <article>
#     <span class="date">Published: 2016-08-23</span>
#     <span class="author">Radiohead</span>
#     <h1>Burn the Witch</h1>
#     <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     <div>
#   </article>
# </body>
# ```
#
# Here, the title of the song is nested three levels deep: `body > article > h1`.
#
# ### Tables
#
# Data is also often stored in HTML tables:
#
# ```html
# <table>
#     <tr>
#         <th></th>
#         <th>The Beatles</th>
#         <th>Led Zeppelin</th>
#     </tr>
#     <tr>
#         <td># Band Members</td>
#         <td>4</td>
#         <td>4</td>
#     </tr>
# </table>
# ```
#
# ### The DOM
#
# As we have seen above, a markup document looks a lot like a tree: it has a root, the HTML element, and elements can have children that are containing elements themselves.
#
# While HTML is a textual representation of a markup document, the DOM is a programming interface for it. Also the DOM represents the state of a page as it's rendered, that (nowadays) doesn't mean that there is an underlying HTML document that corresponds to that exactly. Rather, the DOM is dynamically generated with, e.g., JavaScript.
#
# In this class we will use “DOM” to mean the tree created by the web browsers to represent the document.
#
# #### Inspecting the DOM in a browser
#
# Perhaps the most important habit when scraping is to investigate the source of a page using the Developer Tools. In this case, we’ll look at the Element tree, by clicking on the menu bar: View → Developer → Developer Tools.
#
# Alternatively, you can right click on any part of the webpage, and choose “Inspect Element”. Notice that there can be a big difference between what is in the DOM and what is in the source.
#
# Take a look at the DOM of [this html page](lyrics.html). Next, we'll scrape the data from this page!

# %% [markdown]
# # Scraping with BeautifulSoup
#
# [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/) is a Python library design for computationally extracting data from html documents. It supports navigating in the DOM and retreiving exactly the data elements you need.
#
# Let's start with a simple example using the [lyrics.html](lyrics.html) file.

# %%
from bs4 import BeautifulSoup

# we tell BeautifulSoup and tell it which parser to use
soup = BeautifulSoup(open("lyrics.html"), "html.parser")
# the output corresponds exactly to the html file
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8">
# <title>Lyrics</title>
# </meta></head>
# <body>
# <article id="zep">
# <span class="date">Published: 2016-08-25</span>
# <span class="author">Led Zeppelin</span>
# <h1>Ramble On</h1>
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# </article>
# <article id="radio">
# <span class="date">Published: 2016-08-23</span>
# <span class="author">Radiohead</span>
# <h1>Burn the Witch</h1>
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>
# </article>
# </body>
# </html>

# %%
# sometimes that can be hard to read, so we can format
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8">
#    <title>
#     Lyrics
#    </title>
#   </meta>
#  </head>
#  <body>
#   <article id="zep">
#    <span class="date">
#     Published: 2016-08-25
#    </span>
#    <span class="author">
#     Led Zeppelin
#    </span>
#    <h1>
#     Ramble On
#    </h1>
#    <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#    </div>
#   </article>
#   <article id="radio">
#    <span class="date">
#     Published: 2016-08-23
#    </span>
#    <span class="author">
#     Radiohead
#    </span>
#    <h1>
#     Burn the Witch
#    </h1>
#    <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#    </div>
#   </article>
#  </body>
# </html>

# %% [markdown]
# We can access content by tags:

# %%
# get the title tag
soup.title
type(soup.title)
# Out:
# bs4.element.Tag

# %% [markdown]
# And get the text out of the tag:

# %%
soup.title.string
# Out:
# 'Lyrics'

# %% [markdown]
# Directly accessing an element works for the first occurence of a tag, we don't get the others.

# %%
soup.div
# Out:
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>

# %% [markdown]
# Here we get formatted text:

# %%
soup.div.string
# Out:
# "\n    Leaves are falling all around, It's time I was on my way.\n    Thanks to you, I'm much obliged for such a pleasant stay.\n    But now it's time for me to go. The autumn moon lights my way.\n    For now I smell the rain, and with it pain, and it's headed my way.\n    "

# %%
print(soup.div.string)
# Out:
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.

# %% [markdown]
# We can use attributes to find specific elements, and get only the text, not the html markup:

# %%
text = soup.find(id="zep").get_text()
print(text)
# Out:
# Published: 2016-08-25
# Led Zeppelin
# Ramble On
#
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.

# %% [markdown]
# We can also use find_all to get all instances of a tag:

# %%
h1s = soup.find_all("h1")
h1s
# Out:
# [<h1>Ramble On</h1>, <h1>Burn the Witch</h1>]

# %% [markdown]
# This returns a list of beautiful soup elements:

# %%
type(h1s[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# It's easy to get the text out of this:

# %%
string_h1s = [tag.get_text() for tag in h1s]
string_h1s
# Out:
# ['Ramble On', 'Burn the Witch']

# %% [markdown]
# Since `find_all` is so commonly used, you can use a shortcut by just calling directly on an object:

# %%
soup("div")
# Out:
# [<div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>, <div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %% [markdown]
# We can address the elements in the returned object directly:

# %%
soup("div")[1]
# Out:
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>

# %% [markdown]
# Or iterate over it:

# %%
for p in soup.find_all("div"):
    print("---")
    print(p)
# Out:
# ---
# <div class="content">
#     Leaves are falling all around, It's time I was on my way.
#     Thanks to you, I'm much obliged for such a pleasant stay.
#     But now it's time for me to go. The autumn moon lights my way.
#     For now I smell the rain, and with it pain, and it's headed my way.
#     </div>
# ---
# <div class="content">
#     Stay in the shadows
#     Cheer at the gallows
#     This is a round up
#     This is a low flying panic attack
#     Sing a song on the jukebox that goes
#     Burn the witch
#     Burn the witch
#     We know where you live
#     </div>

# %% [markdown]
# ### CSS Selectors
#
# We can also use CSS selectors. CSS Selectors apply, among others, to elements, classes, and IDs.
#
#
# ```CSS
# /* Element Selector */
# article {
#   color: FireBrick;
# }
#
# /* ID selector */
# #myID {
#   color: Tomato;
# }
#
# /* Class selector */
# .myClass {
#   color: Aquamarine;
# }
#
# /* Child selector. Only DIRECT children match */
# p > b {
#   color: SteelBlue;
# }
#
# /* Descendant selector. Every time a b is nested within a div this matches */
# div b {
#   color: green;
# }
#
# ```
#
# [Here is an example](https://jsfiddle.net/gxhqv26m/1/) with all the important selectors.
#
# Let's try this in Python:

# %%
# selecting all elements of class .content
soup.select(".content")
# Out:
# [<div class="content">
#      Leaves are falling all around, It's time I was on my way.
#      Thanks to you, I'm much obliged for such a pleasant stay.
#      But now it's time for me to go. The autumn moon lights my way.
#      For now I smell the rain, and with it pain, and it's headed my way.
#      </div>, <div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %%
# selecting all divs that are somewhere below the id radio in the tree
soup.select("#radio div")
# Out:
# [<div class="content">
#      Stay in the shadows
#      Cheer at the gallows
#      This is a round up
#      This is a low flying panic attack
#      Sing a song on the jukebox that goes
#      Burn the witch
#      Burn the witch
#      We know where you live
#      </div>]

# %% [markdown]
# OK, now we know how to extract information out of a website. Now let's look at a complete example.

# %% [markdown]
# ## Fetching a Website
#
# Downloading websites is easy and very efficient. It turns out, that you can cause quite high load on a server when you scrape a lot. So webmasters usually publish what kinds of scraping they allow on their websites. You should check out the robots.txt of a domain before crawling excessively. Let's take a look at [Google Scholar's robots.txt](https://scholar.google.com/robots.txt):
#
# ```
# User-agent: *
# Disallow: /search
# Allow: /search/about
# Disallow: /sdch
# Disallow: /groups
# Disallow: /index.html?
# Disallow: /?
# Allow: /?hl=
# ...
# Disallow: /scholar
# Disallow: /citations?
# ...
# ```
#
# Here it specifies that you're not allowed to crawl a lot of the pages. The `/scholar` subdirectory is especially painful because it prohibits you from generating queries dynamically.
#
# It's also common that sites ask you to delay crawiling:
#
# ```
# Crawl-delay: 30
# Request-rate: 1/30
# ```
#
# You should respect those restrictions. Now, no one can stop you from running a request through a crawler, but sites like google scholar will block you VERY quickly if you request to many pages in a short time-frame.
#
# Larger websites also often have explicit terms that state their policy on crawling.
#
# An alternative strategy to dynamic crawling (as we're doing in the next example) is to download a local copy of the website and crawl that. This ensures that you hit the site only once per page. A good tool to achieve that is [wget](https://www.gnu.org/software/wget/).

# %% [markdown]
# ### Example: Utah's course enrollments
#
# We're going to build a dataset of classes offered this fall at the U and look at the enrollment numbers. We'll use the catalog listed here:
# https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/
#
# The U doesn't seem to care whether/how we crawl the websites. There is no robots.txt: http://www.utah.edu/robots.txt
#
# We'll use the [`urllib.request`](https://docs.python.org/3.0/library/urllib.request.html) library to retreive the websites.

# %%
import urllib.request
url = "https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/"
# here we actually access the website
with urllib.request.urlopen(url) as response:
   html = response.read()
# here it's already a local operation
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# Let's take a look at the first 5000 lines of this page:

# %%
print(soup.prettify()[0:5000])
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Class Schedules
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="//templates.utah.edu/apps/v1/_css/main.css" rel="stylesheet"/>
#   <link href="/uofu/stu/ClassSchedules/css/styles.css" rel="stylesheet" type="text/css"/>
#   <link href="/uofu/stu/ClassSchedules/css/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <meta content="IE=10; IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/>
#   <script src="//templates.utah.edu/apps/v1/_js/vendor/modernizr-2.6.2.min.js">
#   </script>
#   <link href="/uofu/stu/ClassSchedules/images/favicon.ico" rel="icon" type="image/ico"/>
#   <script src="/uofu/stu/ClassSchedules/scripts/jquery.min.js">
#   </script>
#   <script src="/uofu/stu/ClassSchedules/scripts/jquery.validate.min.js">
#   </script>
#   <script src="/uofu/stu/ClassSchedules/scripts/elevator.js">
#   </script>
#   <script>
#    $(window).load(function(){
#                 var elevator = new Elevator({
#                     mainAudio: "/uofu/stu/ClassSchedules/resources/bg.mp3",
#                     endAudio: "/uofu/stu/ClassSchedules/resources/ding.mp3"
#                 });
#
#                 $('.elevator-button').on('click', function(e) {
#                     if (e.altKey) {
#                         e.preventDefault();
#                         elevator.elevate();
#                     } else {
#                         $('body').scrollTop(0);
#                     }
#                 });
#             });
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r;
#                 i[r] = i[r] || function ()
#                 {
#                     (i[r].q = i[r].q || []).push(arguments)
#                 }
#                 , i[r].l = 1 * new Date();
#                 a = s.createElement(o),
#                         m = s.getElementsByTagName(o)[0];
#                 a.async = 1;
#                 a.src = g;
#                 m.parentNode.insertBefore(a, m)
#             })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#             ga('create', 'UA-58881890-50', 'auto');
#             ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  </head>
#  <body>
#   <header class="uu-header" id="top" role="banner">
#    <div class="uu-container">
#     <a class="skip sr-only focusable" href="#uu-skip-target">
#      Skip to Main Content
#     </a>
#     <div class="row">
#      <!-- header logo 1 -->
#      <div class="col-sm-6">
#       <div class="uu-logo">
#        <a href="http://www.utah.edu/">
#         <img alt="The University of Utah" src="/uofu/stu/ClassSchedules/images/U.png"/>
#        </a>
#       </div>
#       <div class="uu-org-title">
#        <h2>
#         <a href="http://www.utah.edu/">
#          <img src="/uofu/stu/ClassSchedules/images/Ulogo.png"/>
#         </a>
#        </h2>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <nav class="uu-nav navbar navbar-inverse" role="navigation">
#    <div class="uu-container">
#     <a class="uu-nav-link" href="index.html">
#      Home
#     </a>
#    </div>
#   </nav>
#   <div class="uu-breadcrumb">
#    <div class="uu-container">
#     <div class="row">
#      <div class="col-sm-7">
#       <section>
#        <h1>
#         Main Campus
#        </h1>
#        <h5 class="subject-info">
#         Fall 2016 Class Schedule
#        </h5>
#       </section>
#      </div>
#      <div class="col-sm-5">
#       <div class="subject-info">
#        <section>
#        </section>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <section>
#    <main class="uu-main class-subject" role="main">
#     <div class="uu-container" id="uu-skip-target">
#      <div class="row">
#       <div class="col-md-10">
#        <table class="table table-bordered table-striped table-responsive">
#         <tr>
#          <th colspan="2">
#           Available U of U Classes
#          </th>
#         </tr>
#         <tr>
#          <td>
#           <a href="attribute_list.html?listType=GEN">
#            Gen Ed &amp; Bachelor Degree Courses
#           </a>
#          </td>
#          <td>
#           FF, FI, AI, CW, DV, IR, etc.
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="attribute_list.html?listType=SESSION">
#            Class Sessions
#           </a>
#          </td>
#          <td>
#           Second, Third and Fourth Session Classes
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="attribute_index.html?type=AOCE">
#            Continuing Education Classes
#           </a>
#          </td>
#          <td>
#           Continuing Education Credit and Non-Credit Classes
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a href="attribute_index.html?type=FLXU">
#            Flexible Classes
#           </a>
#          </td>
#          <td>
#           FLXU
#          </td>
#         </tr>
#         <tr>
#          <td>

# %% [markdown]
# What we want to get out of this page is the link to the subject specific course lists.
#
# While you could find this in the text output in python, it's much easier to find the relevant parts in your browser's built in inspector. Here, we've highlighted one of the subjects (Anesthesiology):
#
# ![Chrome Inspector](inspector.png)

# %% [markdown]
# This is the relevant HTML snippet:
#
# ```html
# <ul class="subject-list">
#   <li class="row"><a class="col-sm-4" href="class_list.html?subject=ANES">ANES</a><span class="col-md-10">Anesthesiology</span></li>
# </ul>
# ```
#
# We can scrape this based on the "subject-list" class attribute.
#
# Let's build a dictionary of subject shorthands to a tuple of the full subject name and links to the relevant courses. For CS this should look like this:
#
# ```
# CS: (Computer Science, https://student.apps.utah.edu/.../1168/class_list.html?subject=CS)
# ```

# %%
subjects = {}

for subject in soup.find_all(class_="subject-list"):
    # the url is relative. 
    # We can get the tail by retrieving the link out the href attribute of the a tag
    link_tail = subject.find("a").get("href")
    # concatenate the base URL and the tail of the link
    link = url + link_tail
    # the subject shortname is embedded within the <a> tag
    subject_short = subject.find("a").get_text()
    # the subject name is embedded within the span 
    subject_long = subject.span.get_text()
    # write it to the dictionary
    subjects[subject_short] = (subject_long, link)

subjects
# Out:
# {'ACCTG': ('Accounting',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ACCTG'),
#  'AEROS': ('Aerospace Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=AEROS'),
#  'ANAT': ('Neurobiology and Anatomy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ANAT'),
#  'ANES': ('Anesthesiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ANES'),
#  'ANTH': ('Anthropology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ANTH'),
#  'ARAB': ('Arabic',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ARAB'),
#  'ARCH': ('Architecture',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ARCH'),
#  'ART': ('Art',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ART'),
#  'ARTH': ('Art History',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ARTH'),
#  'ASL': ('American Sign Language',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ASL'),
#  'ASTP': ('Asian Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ASTP'),
#  'ASTR': ('Astronomy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ASTR'),
#  'ATHL': ('Athletics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ATHL'),
#  'ATMOS': ('Atmospheric Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ATMOS'),
#  'ATSM': ('Athletic Training and Sports Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ATSM'),
#  'BALLE': ('Ballet',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=BALLE'),
#  'BART': ('Book Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=BART'),
#  'BIO C': ('Biochemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=BIO+C'),
#  'BIOEN': ('Bioengineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=BIOEN'),
#  'BIOL': ('Biology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=BIOL'),
#  'BLCHM': ('Biological Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=BLCHM'),
#  'BMI': ('Biomedical Informatics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=BMI'),
#  'BUS': ('Business',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=BUS'),
#  'CAMB': ('Cambodian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CAMB'),
#  'CERM': ('Ceramics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CERM'),
#  'CH EN': ('Chemical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CH+EN'),
#  'CHEM': ('Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CHEM'),
#  'CHIN': ('Chinese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CHIN'),
#  'CL CV': ('Classical Civilization',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CL+CV'),
#  'CLCS': ('Comparative Literary and Cultural Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CLCS'),
#  'CMP': ('City & Metropolitan Planning',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CMP'),
#  'COMM': ('Communication',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=COMM'),
#  'COPTC': ('Coptic Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=COPTC'),
#  'CS': ('Computer Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CS'),
#  'CSD': ('Communication Sciences and Disorders',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CSD'),
#  'CTLE': ('Center for Teaching & Learning Excellence',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CTLE'),
#  'CVEEN': ('Civil and Environmental Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CVEEN'),
#  'DANC': ('Modern Dance',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=DANC'),
#  'DENT': ('Dentistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=DENT'),
#  'DERM': ('Dermatology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=DERM'),
#  'DES': ('Design',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=DES'),
#  'DRAW': ('Drawing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=DRAW'),
#  'EAE': ('Entertainment Arts & Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=EAE'),
#  'EAS': ('English for Academic Success',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=EAS'),
#  'ECE': ('Electrical and Computer Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ECE'),
#  'ECON': ('Economics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ECON'),
#  'ECS': ('Education, Culture and Society',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ECS'),
#  'ED PS': ('Educational Psychology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ED+PS'),
#  'EDTEC': ('Educational Technology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=EDTEC'),
#  'EDU': ('Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=EDU'),
#  'EHUM': ('Environmental Humanities',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=EHUM'),
#  'ELI': ('English Language Institute',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ELI'),
#  'ELP': ('Educational Leadership & Policy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ELP'),
#  'ENGIN': ('Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ENGIN'),
#  'ENGL': ('English',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ENGL'),
#  'ENTP': ('Entrepreneurship',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ENTP'),
#  'ENVST': ('Environmental and Sustainability Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ENVST'),
#  'ESSF': ('ESS Fitness Courses',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ESSF'),
#  'ETHNC': ('Ethnic Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ETHNC'),
#  'FA': ('Fine Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=FA'),
#  'FCS': ('Family and Consumer Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=FCS'),
#  'FILM': ('Film and Media Arts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=FILM'),
#  'FINAN': ('Finance',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=FINAN'),
#  'FP MD': ('Family and Preventive Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=FP+MD'),
#  'FRNCH': ('French',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=FRNCH'),
#  'GEO': ('Geology and Geophysics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=GEO'),
#  'GEOG': ('Geography',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=GEOG'),
#  'GERM': ('German',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=GERM'),
#  'GERON': ('Gerontology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=GERON'),
#  'GNDR': ('Gender Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=GNDR'),
#  'GREEK': ('Greek',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=GREEK'),
#  'H EDU': ('Health Promotion & Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=H+EDU'),
#  'H GEN': ('Human Genetics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=H+GEN'),
#  'HEBR': ('Hebrew',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=HEBR'),
#  'HINDI': ('Hindi',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=HINDI'),
#  'HIST': ('History',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=HIST'),
#  'HNKLY': ('Hinckley Institute',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=HNKLY'),
#  'HONOR': ('Honors College',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=HONOR'),
#  'HSP': ('Health, Society and Policy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=HSP'),
#  'HUM': ('Humanities',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=HUM'),
#  'IAGE': ('International Affairs and Global Enterprise',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=IAGE'),
#  'INTMD': ('Internal Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=INTMD'),
#  'IS': ('Information Systems',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=IS'),
#  'ITAL': ('Italian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ITAL'),
#  'JAPAN': ('Japanese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=JAPAN'),
#  'KINES': ('Kinesiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=KINES'),
#  'KOREA': ('Korean',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=KOREA'),
#  'LANG': ('Languages and Literature',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LANG'),
#  'LAS': ('Latin American Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LAS'),
#  'LATIN': ('Latin',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LATIN'),
#  'LAW': ('Law',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LAW'),
#  'LDRSP': ('Leadership',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LDRSP'),
#  'LEAP': ('LEAP Program',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LEAP'),
#  'LING': ('Linguistics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LING'),
#  'LLART': ('Art and Photography',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLART'),
#  'LLBUS': ('Business and Finance',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLBUS'),
#  'LLCFT': ('Crafts',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLCFT'),
#  'LLFW': ('Food and Wine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLFW'),
#  'LLHG': ('Home and Garden',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLHG'),
#  'LLHL': ('Healthy Living',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLHL'),
#  'LLLAN': ('Language',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLLAN'),
#  'LLMT': ('Music and Theatre',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLMT'),
#  'LLPOT': ('Potpourri',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLPOT'),
#  'LLREC': ('Recreation',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLREC'),
#  'LLWRC': ('Writing/Creative',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=LLWRC'),
#  'MATH': ('Mathematics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MATH'),
#  'MBIOL': ('Molecular Biology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MBIOL'),
#  'MD CH': ('Pharmacy - Medicinal Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MD+CH'),
#  'MD ID': ('Interdepartmental Medicine',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MD+ID'),
#  'MD LB': ('Medical Laboratory Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MD+LB'),
#  'MDCRC': ('Clinical Research Center',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MDCRC'),
#  'ME EN': ('Mechanical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ME+EN'),
#  'MET E': ('Metallurgical Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MET+E'),
#  'MG EN': ('Mining Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MG+EN'),
#  'MGT': ('Management',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MGT'),
#  'MHA': ('Master Healthcare Administration',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MHA'),
#  'MID E': ('Middle East Language and Area Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MID+E'),
#  'MIL S': ('Military Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MIL+S'),
#  'MKTG': ('Marketing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MKTG'),
#  'MSE': ('Materials Science and Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MSE'),
#  'MST': ('Master of Science and Technology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MST'),
#  'MUSC': ('Music',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MUSC'),
#  'NAHTL': ('Nahuatl',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NAHTL'),
#  'NAVJO': ('Navajo',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NAVJO'),
#  'NEURO': ('Neurology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NEURO'),
#  'NEUSC': ('Neuroscience',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NEUSC'),
#  'NSURG': ('Neurosurgery',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NSURG'),
#  'NUCL': ('Nuclear Engineering',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NUCL'),
#  'NUIP': ('Nutrition and Integrative Physiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NUIP'),
#  'NURS': ('Nursing',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NURS'),
#  'NUTR': ('Nutrition',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NUTR'),
#  'NV SC': ('Naval Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=NV+SC'),
#  'OBST': ('Obstetrics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=OBST'),
#  'OC TH': ('Occupational Therapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=OC+TH'),
#  'OIS': ('Operations and Information Systems',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=OIS'),
#  'ONCSC': ('Oncological Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ONCSC'),
#  'OPHTH': ('Ophthalmology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=OPHTH'),
#  'ORTHO': ('Orthopedics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=ORTHO'),
#  'OSHER': ('Osher Lifelong Learning',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=OSHER'),
#  'PADMN': ('Public Administration',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PADMN'),
#  'PATH': ('Pathology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PATH'),
#  'PCS': ('Peace and Conflict Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PCS'),
#  'PCTH': ('Pharmacotherapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PCTH'),
#  'PED': ('Pediatrics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PED'),
#  'PERS': ('Persian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PERS'),
#  'PH MD': ('Phys Med & Rehabilitation',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PH+MD'),
#  'PH TH': ('Physical Therapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PH+TH'),
#  'PH TX': ('Pharmacology and Toxicology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PH+TX'),
#  'PHARM': ('Pharmacy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PHARM'),
#  'PHCEU': ('Pharmaceutics and Pharmaceutical Chemistry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PHCEU'),
#  'PHIL': ('Philosophy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PHIL'),
#  'PHS': ('Population Health Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PHS'),
#  'PHYS': ('Physics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PHYS'),
#  'PHYSL': ('Physiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PHYSL'),
#  'POLS': ('Political Science',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=POLS'),
#  'PREP': ('Preparatory',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PREP'),
#  'PRINT': ('Printmaking',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PRINT'),
#  'PROEA': ('Professional Education Academies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PROEA'),
#  'PROED': ('Professional Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PROED'),
#  'PROTA': ('Professional Education Technology Academy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PROTA'),
#  'PRT': ('Parks, Recreation and Tourism',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PRT'),
#  'PRTL': ('PRT Outdoor Adventure - Land',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PRTL'),
#  'PRTS': ('PRT Outdoor Adventure - Snow',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PRTS'),
#  'PRTW': ('PRT Outdoor Adventure - Water',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PRTW'),
#  'PSY': ('Psychology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PSY'),
#  'PSYCT': ('Psychiatry',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PSYCT'),
#  'PTGSE': ('Portuguese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PTGSE'),
#  'PUBPL': ('Public Policy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=PUBPL'),
#  'QUECH': ('Quechua',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=QUECH'),
#  'RDLGY': ('Radiology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=RDLGY'),
#  'RDONC': ('Radiation Oncology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=RDONC'),
#  'RECTH': ('Recreational Therapy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=RECTH'),
#  'REDEV': ('Real Estate Development',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=REDEV'),
#  'RELS': ('Religious Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=RELS'),
#  'RHSCI': ('Rehabilitation Sciences',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=RHSCI'),
#  'RUSS': ('Russian',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=RUSS'),
#  'SCLPT': ('Sculpture/Intermedia',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=SCLPT'),
#  'SOC': ('Sociology',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=SOC'),
#  'SP ED': ('Special Education',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=SP+ED'),
#  'SPAN': ('Spanish',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=SPAN'),
#  'SR EL': ('Senior Electives',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=SR+EL'),
#  'STAT': ('Statistics',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=STAT'),
#  'STRAT': ('Strategy',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=STRAT'),
#  'SURG': ('Surgery',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=SURG'),
#  'SUST': ('Sustainability',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=SUST'),
#  'SW': ('Social Work',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=SW'),
#  'TESPC': ('Tech Ed Spec Client',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=TESPC'),
#  'THEA': ('Theatre',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=THEA'),
#  'UC': ('University College Academic Advising',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=UC'),
#  'UGS': ('Undergraduate Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=UGS'),
#  'UUHSC': ('Health Sciences Center',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=UUHSC'),
#  'VIET': ('Vietnamese',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=VIET'),
#  'WRTG': ('Writing and Rhetoric Studies',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=WRTG'),
#  'YEHS': ('High School',
#   'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=YEHS')}

# %% [markdown]
# Let's look at the entry for math:

# %%
subjects["MATH"]
# Out:
# ('Mathematics',
#  'https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=MATH')

# %% [markdown]
# That's what we want.
#
# As an aside: we could have taken a different approach here. Note how the URL has a deterministic query parameter that matches the subject:
#
# ```
# class_list.html?subject=MATH
# ```
#
# We could use this to also retrieve the links if we only hat the short subject shortnames.

# %% [markdown]
# #### Getting a list of classes
#
# Next, it's time to get the courses. Let's look at the [website for CS](https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/class_list.html?subject=CS).
#
# We'll fetch this class in a fucntion where that we pass the subject name:

# %%
def getCourses(subject):
    """ 
    Retrieve a website based on the subject short name and return it as a BeautifulSoup object. 
    Assumes an existing subjects dictionary.
    """
    if (not subject in subjects):
        print("Unknown subject " + subject)
    else:
        url = subjects[subject][1]
        with urllib.request.urlopen(url) as response:
           subject_html = response.read()
        classSoup = BeautifulSoup(subject_html, 'html.parser')
        return classSoup

# %% [markdown]
# Let's run this function for CS and look at the output:

# %%
classSoup = getCourses("CS")
print(classSoup.prettify()[0:5000])
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Class Schedule
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="//templates.utah.edu/apps/v1/_css/main.css" rel="stylesheet"/>
#   <link href="/uofu/stu/ClassSchedules/css/styles.css" rel="stylesheet" type="text/css"/>
#   <link href="/uofu/stu/ClassSchedules/css/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <meta content="IE=10; IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/>
#   <script src="//templates.utah.edu/apps/v1/_js/vendor/modernizr-2.6.2.min.js">
#   </script>
#   <link href="/uofu/stu/ClassSchedules/images/favicon.ico" rel="icon" type="image/ico"/>
#   <script src="/uofu/stu/ClassSchedules/scripts/jquery.min.js">
#   </script>
#   <script src="/uofu/stu/ClassSchedules/scripts/jquery.validate.min.js">
#   </script>
#   <script src="/uofu/stu/ClassSchedules/scripts/elevator.js">
#   </script>
#   <script>
#    $(window).load(function(){
#                 var elevator = new Elevator({
#                     mainAudio: "/uofu/stu/ClassSchedules/resources/bg.mp3",
#                     endAudio: "/uofu/stu/ClassSchedules/resources/ding.mp3"
#                 });
#
#                 $('.elevator-button').on('click', function(e) {
#                     if (e.altKey) {
#                         e.preventDefault();
#                         elevator.elevate();
#                     } else {
#                         $('body').scrollTop(0);
#                     }
#                 });
#             });
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r;
#                 i[r] = i[r] || function ()
#                 {
#                     (i[r].q = i[r].q || []).push(arguments)
#                 }
#                 , i[r].l = 1 * new Date();
#                 a = s.createElement(o),
#                         m = s.getElementsByTagName(o)[0];
#                 a.async = 1;
#                 a.src = g;
#                 m.parentNode.insertBefore(a, m)
#             })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#             ga('create', 'UA-58881890-50', 'auto');
#             ga('send', 'pageview');
#   </script>
#   <meta charset="utf-8"/>
#  </head>
#  <body>
#   <header class="uu-header" id="top" role="banner">
#    <div class="uu-container">
#     <a class="skip sr-only focusable" href="#uu-skip-target">
#      Skip to Main Content
#     </a>
#     <div class="row">
#      <!-- header logo 1 -->
#      <div class="col-sm-6">
#       <div class="uu-logo">
#        <a href="http://www.utah.edu/">
#         <img alt="The University of Utah" src="/uofu/stu/ClassSchedules/images/U.png"/>
#        </a>
#       </div>
#       <div class="uu-org-title">
#        <h2>
#         <a href="http://www.utah.edu/">
#          <img src="/uofu/stu/ClassSchedules/images/Ulogo.png"/>
#         </a>
#        </h2>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <nav class="uu-nav navbar navbar-inverse" role="navigation">
#    <div class="uu-container">
#     <a class="uu-nav-link" href="index.html">
#      Home
#     </a>
#    </div>
#   </nav>
#   <div class="uu-breadcrumb">
#    <div class="uu-container">
#     <div class="row">
#      <div class="col-sm-7">
#       <section>
#        <h1>
#         Computer Science
#        </h1>
#        <h5 class="subject-info">
#         Fall 2016 Class Schedule
#        </h5>
#       </section>
#      </div>
#      <div class="col-sm-5">
#       <div class="subject-info">
#        <section>
#         <ul>
#          <li>
#           Location: MEB 3190
#          </li>
#          <li>
#           Phone: 801-581-8224
#          </li>
#         </ul>
#        </section>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <section>
#    <!-- ************* MAIN CONTENT AREA ****************** -->
#    <main class="uu-main class-details" role="main">
#     <div class="uu-container" id="uu-skip-target">
#      <div class="top-content">
#       <div class="row">
#        <div class="col-sm-8">
#         <div class="panel panel-default">
#          <div class="panel-heading">
#           Departmental Notes
#          </div>
#          <div class="panel-body">
#           <p>
#            <span>
#             For course descriptions and pre-requisite information click on the subject column next to the appropriate catalog number.
#            </span>
#           </p>
#           <p>
#            <span>
#             THIS DEPARTMENT ENFORCES UNDERGRADUATE PREREQUISITES. Please note that the registration system may not factor in transfer work when determining if prerequisites have been met.   If you are unable to register for a course and think you have met the prerequisite(s), please contact an advisor from this department to inquire about obtaining a permission code.  You may be administratively dropped from a course if the prerequisite has not been met.
#            </span>
#           </p>
#          </div>
#         </div>
#        </div>

# %% [markdown]
# Again, that's easier to look at in the inspector.

# %% [markdown]
# ![Class Site Inspected](class.png)
#
# The data is stored in a table that has the ID `classDetailsTable`. Let's extract that table:

# %%
# now we check out an example to see what a good characteristic is
classTable = classSoup.find(id="classDetailsTable")
print(classTable)
# Out:
# <table class="table table-bordered table-striped main-table" id="classDetailsTable">
# <thead><tr>
# <th class="nowrap">Class #</th>
# <th>Subject <span class="glyphs"></span></th>
# <th class="nowrap">Cat. #</th>
# <th>Sec.</th>
# <th>Component</th>
# <th>Units</th>
# <th>Title</th>
# <th class="nowrap">Days/Time &amp; Session</th>
# <th>Location</th>
# <th><a href="#">Class Attrs</a></th>
# <th>Instructor</th>
# <th><a href="#">Feed back</a></th>
# <th>Pre Req</th>
# <th>Fees</th>
# </tr>
# </thead>
# <tr class="even">
# <td><a name="18857"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=350&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=350">350</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  0.0</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?type=AOCE">AOCE</a>
# </p>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0297211/teaching/index.hml" target="_blank">KOPTA, D. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Section 8 belongs to this lecture. Student will automatically be registered for this lecture when registering for 008 discussion section. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 3500 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="18859"></a><span>18859</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=350&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=350">350</a>
# </td>
# <td>008</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?type=AOCE">AOCE</a>
# </p>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0297211/teaching/index.hml" target="_blank">KOPTA, D. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td><span>$605.00</span></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Section 1 belongs to this discussion. Student will automatically be registered for this lecture when registering for this section. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 3500 008</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="9894"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~parker/1030_F16.html">Foundations of CS</a>
# </td>
# <td class="nowrap">
# <p><span>MW</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 8 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. Some students may waive CS 1030 and go directly into CS 1410. To determine whether you should begin your programming coursework with CS 1030 or CS 1410, go to www.cs.utah.edu/~parker/instructions to take the proficiency test. This is REQUIRED prior to registration. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="9896"></a><span>9896</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 002</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="9897"></a><span>9897</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 003</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="9898"></a><span>9898</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>05:15PM-06:05PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 004</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="9899"></a><span>9899</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 005</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="10967"></a><span>10967</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 006</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="12992"></a><span>12992</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>007</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 007</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="14035"></a><span>14035</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 008</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="5100"></a><span>5100</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1040&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1040">1040</a>
# </td>
# <td>090</td>
# <td>Laboratory</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Creating Web Content</span>
# </td>
# <td class="nowrap">
# <p>TBA<br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?type=ONLN">ONLN</a>
# </p>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7963" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td><span>$60.00</span></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This is an online course, which does not meet in-class. For additional information, please visit <a href="http://uonline.utah.edu" target="_blank">http://uonline.utah.edu</a> or call 585-5959. </span>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="1177"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="https://www.cs.utah.edu/~dejohnso/CS1410_F16.html">Object-Oriented Prog</a>
# </td>
# <td class="nowrap">
# <p><span>MWF</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 7 belong to this lecture. This section is intended for Computer Science pre-majors only. Computer Engineering and Electrical Engineering majors and pre-majors should register in sections 030 or 040, respectively. This course requires registration for a lab section. Students will be automatically registered for this lecture section when registering for the pertinent lab section. In order to register for this course, students must have completed or waived CS 1030. Go to www.cs.utah.edu/~parker/instructions for the proficiency test required to waive CS 1030. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="1698"></a><span>1698</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="1699"></a><span>1699</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="1700"></a><span>1700</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="1701"></a><span>1701</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="1702"></a><span>1702</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="11038"></a><span>11038</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>007</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15519"></a><span>15519</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="11020"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>030</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~parker/1410_30_F16.html">Object-Oriented Prog</a>
# </td>
# <td class="nowrap">
# <p><span>MW</span> / <span>08:05AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L105</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 31-35 belong to this lecture. This section is an embedded systems version of CS 1410, required by Computer Engineering majors and pre-majors. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. This section is an embedded systems version of CS 1410. In order to register, students must have completed or waived CS 1030. Go to www.cs.utah.edu/~parker/instructions for the proficiency test required to waive CS 1030. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 040</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="11021"></a><span>11021</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>031</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 041</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="11022"></a><span>11022</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>032</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 042</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="11023"></a><span>11023</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>033</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 043</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="11564"></a><span>11564</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>034</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 044</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13211"></a><span>13211</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>035</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 045</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="13629"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>040</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~parker/1410_30_F16.html">Object-Oriented Prog</a>
# </td>
# <td class="nowrap">
# <p><span>MW</span> / <span>08:05AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L105</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 041 - 045 belong to this lecture. This section is an embedded systems version of CS 1410, and is restricted to Electrical Engineering majors and pre-majors. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. The CS 1030 prerequisite is waived for EE students registering for this section. Students must fill out a web form at <a href="http://www.ece.utah.edu/course_perms" target="_blank">http://www.ece.utah.edu/course_perms</a> to get a permission code. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 030</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13630"></a><span>13630</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>041</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 031</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="13631"></a><span>13631</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>042</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 032</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13632"></a><span>13632</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>043</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 033</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="13633"></a><span>13633</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>044</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 034</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13637"></a><span>13637</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>045</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 035</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="4794"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0849246/teaching/index.hml" target="_blank">RAKAMARIC, Z.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1148&amp;class_nbr=5015" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 4 belong to this lecture. This course requires registration for a discussion section. Students will be automatically registered for this lecture section when registering for the discussion section. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="6453"></a><span>6453</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>002</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L112</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0849246/teaching/index.hml" target="_blank">RAKAMARIC, Z.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1148&amp;class_nbr=5015" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6454"></a><span>6454</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>003</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L122</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0849246/teaching/index.hml" target="_blank">RAKAMARIC, Z.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1148&amp;class_nbr=5015" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6455"></a><span>6455</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>004</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L122</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0849246/teaching/index.hml" target="_blank">RAKAMARIC, Z.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1148&amp;class_nbr=5015" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="13881"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>MW</span> / <span>03:00PM-04:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2-5 belong to this section. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13882"></a><span>13882</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="13883"></a><span>13883</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="13884"></a><span>13884</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="13885"></a><span>13885</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15897"></a><span>15897</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="9973"></a><span>9973</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2963&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2963">2963</a>
# </td>
# <td>001</td>
# <td>Lab/ Discussion</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>LPI Level 1</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>06:00PM-09:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=ANNEX" target="_blank">ANNEX 2214</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?type=FLXU">FLXU</a>
# </p>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0708330/teaching/index.hml" target="_blank">TOPONCE, A. S.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td><span>$1,500.00</span></td>
# </tr>
# <tr class="even">
# <td><a name="10932"></a><span>10932</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3020&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3020">3020</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="http://www.coe.utah.edu/~cs3020/">Research Forum</a>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>09:10AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0029780/teaching/index.hml" target="_blank">HOLLERBACH, J. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6083"></a><span>6083</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3100">3100</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Models Of Computation</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>10:45AM-12:05PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=QI">QI</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=6336" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="9975"></a><span>9975</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3130&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3130">3130</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Eng Prob Stats</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>03:40PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=QI">QI</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0467708/teaching/index.hml" target="_blank">FLETCHER, P. T.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=10685" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 3530 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="1181"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0297211/teaching/index.hml" target="_blank">KOPTA, D. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 8 belongs to this lecture. This course requires registration for a discussion section. Students will be automatically registered for this lecture section when registering for the pertinent discussion section. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS  350 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="1722"></a><span>1722</span></td>
# <td>
# ...
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=16764" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="14045"></a><span>14045</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6964&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6964">6964</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Caching Networks</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>09:10AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6007330/teaching/index.hml" target="_blank">JI, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 2102 (Conference room) </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 6960 007</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="16805"></a><span>16805</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6967&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6967">6967</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="http://graphics.cs.utah.edu/courses/cs6967/fall2016/">Numerical Simulation</a>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0852752/teaching/index.hml" target="_blank">YUKSEL, C.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="16806"></a><span>16806</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6968&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6968">6968</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Clustering</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 2325</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0548623/teaching/index.hml" target="_blank">VENKATASUBRAMANIAN, S.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6456"></a><span>6456</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7930&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7930">7930</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Colloquium</span>
# </td>
# <td class="nowrap">
# <p><span>MWF</span> / <span>09:40AM-11:35AM</span> <br/>
# </p>
# <p><span>TH</span> / <span>03:40PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 1230</a>
# </p>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6002596/teaching/index.hml" target="_blank">HERMANS, T.</a>
# </p>
# <p>
# <a href="http://faculty.utah.edu/u6002596/teaching/index.hml" target="_blank">HERMANS, T.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=8027" target="_blank">View</a>
# </p>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=8027" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="11348"></a><span>11348</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7931&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7931">7931</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Machine Learning Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>01:25PM-02:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6001941/teaching/index.hml" target="_blank">BHASKARA, A.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6888"></a><span>6888</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7932&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7932">7932</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~tch/CS7932F2016">Img Motion Estmtn and Intprtn</a>
# </td>
# <td class="nowrap">
# <p>TBA<br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0030110/teaching/index.hml" target="_blank">HENDERSON, T. C.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="9231"></a><span>9231</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7933&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7933">7933</a>
# </td>
# <td>002</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Graphics Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>12:00PM-02:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0852752/teaching/index.hml" target="_blank">YUKSEL, C.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6889"></a><span>6889</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7934&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7934">7934</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <a href="http://www.eng.utah.edu/~csl-sem/">Computer Systems Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>02:00PM-03:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 1460</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0031750/teaching/index.hml" target="_blank">EIDE, E. N.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="16223"></a><span>16223</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7935&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7935">7935</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Distributed Linear Algebra</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>09:10AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0978964/teaching/index.hml" target="_blank">SUNDAR, H.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=18537" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This seminar will focus on distributed linear algebra algorithms. Attendees will read and discuss papers on core large-scale Linear Algebra algorithms such as dense matrix representations, matrix factorizations, singular value decomposition etc. Attendees will typically discuss one paper each week. </span>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="15505"></a><span>15505</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7936&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7936">7936</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Security Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3515</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0982243/teaching/index.hml" target="_blank">DENNING, T.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="13134"></a><span>13134</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7937&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7937">7937</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Arch/VLSI</span>
# </td>
# <td class="nowrap">
# <p>TBA<br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0415400/teaching/index.hml" target="_blank">BALASUBRAMONIAN, R.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=10896" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 2180 </span>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="8960"></a><span>8960</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7938&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7938">7938</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Image Analysis Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>M</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 3760</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0492366/teaching/index.hml" target="_blank">JOSHI, S.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>BIOEN 6810 001</li>
# <li>ECE 6960 006</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="7224"></a><span>7224</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7939&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7939">7939</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Robotics</span>
# </td>
# <td class="nowrap">
# <p><span>H</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6002596/teaching/index.hml" target="_blank">HERMANS, T.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ME EN 7960 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="16174"></a><span>16174</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7940&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7940">7940</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Performance Optimization</span>
# </td>
# <td class="nowrap">
# <p><span>M</span> / <span>11:50AM-01:10PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0636183/teaching/index.hml" target="_blank">HALL, M. W.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=18482" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3445. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13528"></a><span>13528</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7941&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7941">7941</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Advanced Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>11:50AM-01:10PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0731785/teaching/index.hml" target="_blank">PHILLIPS, B. W.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="9046"></a><span>9046</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7942&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7942">7942</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Visualization Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 3760</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6002873/teaching/index.hml" target="_blank">LEX, A.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class will meet in WEB 3780. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="18133"></a><span>18133</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7960&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7960">7960</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~rajeev/cs7960">Neuromorphic Architectures</a>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 1225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0415400/teaching/index.hml" target="_blank">BALASUBRAMONIAN, R.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 7960 001</li>
# </ul>
# </p>
# </td>
# </tr>
# </table>

# %% [markdown]
# When we have a table, there is an easy way to get the data out - use the magic of Pandas data import functions. There is a sophisticated [`read_html()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_html.html) function. To use this, we'll need a new package:
#
# ```
# conda install -c anaconda html5lib
# ```
#
# Once installed, we can pass in the table as a string:

# %%
import pandas as pd

classes = pd.read_html(str(classTable))[0]
classes.head()
# Out:
#                                              Class # Subject   Cat. #  Sec.  \
# 0                                                NaN       CS   350.0   1.0
# 1  Section 8 belongs to this lecture. Student wil...      NaN     NaN   NaN
# 2                                              18859       CS   350.0   8.0
# 3  Section 1 belongs to this discussion. Student ...      NaN     NaN   NaN
# 4                                                NaN       CS  1030.0   1.0
#
#     Component Units              Title   Days/Time & Session  Location  \
# 0     Lecture   0.0  Software Practice  TH / 02:00PM-03:20PM  WEB L104
# 1         NaN   NaN                NaN                   NaN       NaN
# 2  Discussion    --  Software Practice   W / 03:05PM-03:55PM  MEB 3225
# 3         NaN   NaN                NaN                   NaN       NaN
# 4     Lecture   3.0  Foundations of CS  MW / 02:00PM-02:50PM  WEB L104
#
#   Class Attrs    Instructor Feed back Pre Req     Fees
# 0        AOCE  KOPTA, D. M.       NaN     NaN      NaN
# 1         NaN           NaN       NaN     NaN      NaN
# 2        AOCE  KOPTA, D. M.       NaN     NaN  $605.00
# 3         NaN           NaN       NaN     NaN      NaN
# 4         NaN    PARKER, D.       NaN       Y      NaN

# %% [markdown]
# This is a table, but it looks like the definition of dirty data. There are extra rows we want to get rid of. It looks like the proper rows have a defined value in the `Sec.` field, so we'll filter out rows that don't have values there.

# %%
mask = pd.notnull(classes["Sec."])
classes[mask]
# Out:
#     Class # Subject   Cat. #  Sec.       Component      Units  \
# 0       NaN       CS   350.0   1.0         Lecture        0.0
# 2     18859       CS   350.0   8.0      Discussion         --
# 4       NaN       CS  1030.0   1.0         Lecture        3.0
# 6      9896       CS  1030.0   2.0      Laboratory         --
# 8      9897       CS  1030.0   3.0      Laboratory         --
# 10     9898       CS  1030.0   4.0      Laboratory         --
# 12     9899       CS  1030.0   5.0      Laboratory         --
# 14    10967       CS  1030.0   6.0      Laboratory         --
# 16    12992       CS  1030.0   7.0      Laboratory         --
# 18    14035       CS  1030.0   8.0      Laboratory         --
# 20     5100       CS  1040.0  90.0      Laboratory        3.0
# 22      NaN       CS  1410.0   1.0         Lecture        4.0
# 24     1698       CS  1410.0   2.0      Laboratory         --
# 25     1699       CS  1410.0   3.0      Laboratory         --
# 26     1700       CS  1410.0   4.0      Laboratory         --
# 27     1701       CS  1410.0   5.0      Laboratory         --
# 28     1702       CS  1410.0   6.0      Laboratory         --
# 29    11038       CS  1410.0   7.0      Laboratory         --
# 30    15519       CS  1410.0   8.0      Laboratory         --
# 31      NaN       CS  1410.0  30.0         Lecture        4.0
# 33    11021       CS  1410.0  31.0      Laboratory         --
# 35    11022       CS  1410.0  32.0      Laboratory         --
# 37    11023       CS  1410.0  33.0      Laboratory         --
# 39    11564       CS  1410.0  34.0      Laboratory         --
# 41    13211       CS  1410.0  35.0      Laboratory         --
# 43      NaN       CS  1410.0  40.0         Lecture        4.0
# 45    13630       CS  1410.0  41.0      Laboratory         --
# 47    13631       CS  1410.0  42.0      Laboratory         --
# 49    13632       CS  1410.0  43.0      Laboratory         --
# 51    13633       CS  1410.0  44.0      Laboratory         --
# ..      ...      ...     ...   ...             ...        ...
# 162    5496       CS  6630.0   1.0         Lecture        3.0
# 164   15859       CS  6630.0   2.0         Lecture        3.0
# 166    9223       CS  6640.0   1.0         Lecture        3.0
# 168   16796       CS  6650.0   1.0         Lecture        3.0
# 170   16993       CS  6670.0   1.0         Lecture        3.0
# 171    5088       CS  6710.0   1.0         Lecture        4.0
# 173   18444       CS  6720.0   1.0         Lecture        3.0
# 175   16482       CS  6810.0   1.0         Lecture        3.0
# 177   17110       CS  6960.0   1.0  Special Topics        3.0
# 178     NaN       CS  6961.0   1.0  Special Topics        3.0
# 180   17186       CS  6961.0   2.0      Laboratory         --
# 182   13635       CS  6962.0   1.0  Special Topics        3.0
# 184   14742       CS  6963.0   1.0  Special Topics        3.0
# 185   14045       CS  6964.0   1.0  Special Topics        3.0
# 187   16805       CS  6967.0   1.0  Special Topics        3.0
# 188   16806       CS  6968.0   1.0  Special Topics        3.0
# 189    6456       CS  7930.0   1.0         Seminar  1.0 - 3.0
# 190   11348       CS  7931.0   1.0         Seminar  1.0 - 3.0
# 191    6888       CS  7932.0   1.0         Seminar  1.0 - 3.0
# 192    9231       CS  7933.0   2.0         Seminar        1.0
# 193    6889       CS  7934.0   1.0         Seminar  1.0 - 3.0
# 194   16223       CS  7935.0   1.0         Seminar  1.0 - 3.0
# 196   15505       CS  7936.0   1.0         Seminar        1.0
# 197   13134       CS  7937.0   1.0         Seminar  1.0 - 3.0
# 199    8960       CS  7938.0   1.0         Seminar        1.0
# 201    7224       CS  7939.0   1.0         Seminar        1.0
# 203   16174       CS  7940.0   1.0         Seminar  1.0 - 3.0
# 205   13528       CS  7941.0   1.0         Seminar  1.0 - 3.0
# 206    9046       CS  7942.0   1.0         Seminar  1.0 - 3.0
# 208   18133       CS  7960.0   1.0  Special Topics        3.0
#
#                              Title  \
# 0                Software Practice
# 2                Software Practice
# 4                Foundations of CS
# 6                Foundations of CS
# 8                Foundations of CS
# 10               Foundations of CS
# 12               Foundations of CS
# 14               Foundations of CS
# 16               Foundations of CS
# 18               Foundations of CS
# 20            Creating Web Content
# 22            Object-Oriented Prog
# 24            Object-Oriented Prog
# 25            Object-Oriented Prog
# 26            Object-Oriented Prog
# 27            Object-Oriented Prog
# 28            Object-Oriented Prog
# 29            Object-Oriented Prog
# 30            Object-Oriented Prog
# 31            Object-Oriented Prog
# 33            Object-Oriented Prog
# 35            Object-Oriented Prog
# 37            Object-Oriented Prog
# 39            Object-Oriented Prog
# 41            Object-Oriented Prog
# 43            Object-Oriented Prog
# 45            Object-Oriented Prog
# 47            Object-Oriented Prog
# 49            Object-Oriented Prog
# 51            Object-Oriented Prog
# ..                             ...
# 162                  Visualization
# 164                  Visualization
# 166               Image Processing
# 168        Perception for Graphics
# 170          Cptr-Aided Geom Des I
# 171            Digital VLSI Design
# 173               Analog IC Design
# 175          Computer Architecture
# 177             Advanced Compilers
# 178             VLSI Memory Design
# 180             VLSI Memory Design
# 182      Programming for Engineers
# 184            Distributed Systems
# 185               Caching Networks
# 187           Numerical Simulation
# 188                     Clustering
# 189                     Colloquium
# 190       Machine Learning Seminar
# 191  Img Motion Estmtn and Intprtn
# 192               Graphics Seminar
# 193       Computer Systems Seminar
# 194     Distributed Linear Algebra
# 196               Security Seminar
# 197                      Arch/VLSI
# 199         Image Analysis Seminar
# 201                       Robotics
# 203       Performance Optimization
# 205               Advanced Seminar
# 206          Visualization Seminar
# 208     Neuromorphic Architectures
#
#                             Days/Time & Session           Location  \
# 0                          TH / 02:00PM-03:20PM           WEB L104
# 2                           W / 03:05PM-03:55PM           MEB 3225
# 4                          MW / 02:00PM-02:50PM           WEB L104
# 6                          TH / 12:55PM-01:45PM           WEB L124
# 8                          TH / 08:35AM-09:25AM           WEB L124
# 10                         TH / 05:15PM-06:05PM           WEB L124
# 12                         TH / 04:10PM-05:00PM           WEB L124
# 14                         TH / 11:50AM-12:40PM           WEB L124
# 16                         TH / 10:45AM-11:35AM           WEB L124
# 18                         TH / 09:40AM-10:30AM           WEB L124
# 20                                          TBA                TBA
# 22                        MWF / 10:45AM-11:35AM           WEB L104
# 24                          T / 09:40AM-10:30AM           MEB 3225
# 25                          T / 10:45AM-11:35AM           MEB 3225
# 26                          T / 11:50AM-12:40PM           MEB 3225
# 27                          T / 12:55PM-01:45PM           MEB 3225
# 28                          T / 02:00PM-02:50PM           MEB 3225
# 29                          T / 08:35AM-09:25AM           MEB 3225
# 30                          T / 03:05PM-03:55PM           MEB 3225
# 31                         MW / 08:05AM-09:25AM           WEB L105
# 33                          F / 09:40AM-10:30AM           WEB L124
# 35                          F / 10:45AM-11:35AM           WEB L124
# 37                          F / 11:50AM-12:40PM           WEB L124
# 39                          F / 12:55PM-01:45PM           WEB L124
# 41                          F / 08:35AM-09:25AM           WEB L124
# 43                         MW / 08:05AM-09:25AM           WEB L105
# 45                          F / 09:40AM-10:30AM           WEB L124
# 47                          F / 10:45AM-11:35AM           WEB L124
# 49                          F / 11:50AM-12:40PM           WEB L124
# 51                          F / 12:55PM-01:45PM           WEB L124
# ..                                          ...                ...
# 162                        TH / 02:00PM-03:20PM           WEB L101
# 164                        TH / 02:00PM-03:20PM           WEB L101
# 166                        MW / 01:25PM-02:45PM           WEB 1230
# 168                        MW / 11:50AM-01:10PM           WEB L122
# 170                        MW / 11:50AM-01:10PM           WEB 2460
# 171                        TH / 05:15PM-06:35PM           WEB 2230
# 173                        TH / 03:40PM-05:00PM           MEB 2325
# 175                        TH / 09:10AM-10:30AM           WEB L102
# 177                        TH / 02:00PM-03:20PM           WEB L122
# 178                        WF / 11:50AM-01:10PM           MEB 1225
# 180                        WF / 10:10AM-01:10PM           MEB 2555
# 182                        MW / 03:00PM-04:20PM           WEB L105
# 184                        TH / 03:40PM-05:00PM           WEB L102
# 185                        TH / 09:10AM-10:30AM              TBA .
# 187                        TH / 02:00PM-03:20PM           MEB 3147
# 188                        TH / 12:25PM-01:45PM           MEB 2325
# 189  MWF / 09:40AM-11:35AM TH / 03:40PM-05:00PM  WEB 1230 MEB 3147
# 190                         W / 01:25PM-02:45PM           MEB 3147
# 191                                         TBA                TBA
# 192                         T / 12:00PM-02:00PM           MEB 3147
# 193                         F / 02:00PM-03:30PM           WEB 1460
# 194                         W / 09:10AM-10:30AM           MEB 3147
# 196                         W / 12:00PM-01:00PM           MEB 3515
# 197                                         TBA                TBA
# 199                         M / 12:00PM-01:00PM           WEB 3760
# 201                         H / 12:55PM-01:45PM           MEB 3147
# 203                         M / 11:50AM-01:10PM              TBA .
# 205                         W / 11:50AM-01:10PM           MEB 3147
# 206                         F / 12:00PM-01:00PM           WEB 3760
# 208                        TH / 02:00PM-03:20PM           MEB 1225
#
#     Class Attrs                    Instructor  Feed back Pre Req     Fees
# 0          AOCE                  KOPTA, D. M.        NaN     NaN      NaN
# 2          AOCE                  KOPTA, D. M.        NaN     NaN  $605.00
# 4           NaN                    PARKER, D.        NaN       Y      NaN
# 6           NaN                    PARKER, D.        NaN       Y      NaN
# 8           NaN                    PARKER, D.        NaN       Y      NaN
# 10          NaN                    PARKER, D.        NaN       Y      NaN
# 12          NaN                    PARKER, D.        NaN       Y      NaN
# 14          NaN                    PARKER, D.        NaN       Y      NaN
# 16          NaN                    PARKER, D.        NaN       Y      NaN
# 18          NaN                    PARKER, D.        NaN       Y      NaN
# 20         ONLN                ZACHARY, J. L.       View     NaN   $60.00
# 22          NaN                JOHNSON, D. E.        NaN       Y      NaN
# 24          NaN                JOHNSON, D. E.        NaN       Y      NaN
# 25          NaN                JOHNSON, D. E.        NaN       Y      NaN
# 26          NaN                JOHNSON, D. E.        NaN       Y      NaN
# 27          NaN                JOHNSON, D. E.        NaN       Y      NaN
# 28          NaN                JOHNSON, D. E.        NaN       Y      NaN
# 29          NaN                JOHNSON, D. E.        NaN       Y      NaN
# 30          NaN                JOHNSON, D. E.        NaN       Y      NaN
# 31          NaN                    PARKER, D.       View       Y      NaN
# 33          NaN                    PARKER, D.       View       Y      NaN
# 35          NaN                    PARKER, D.       View       Y      NaN
# 37          NaN                    PARKER, D.       View       Y      NaN
# 39          NaN                    PARKER, D.       View       Y      NaN
# 41          NaN                    PARKER, D.       View       Y      NaN
# 43          NaN                    PARKER, D.       View       Y      NaN
# 45          NaN                    PARKER, D.       View       Y      NaN
# 47          NaN                    PARKER, D.       View       Y      NaN
# 49          NaN                    PARKER, D.       View       Y      NaN
# 51          NaN                    PARKER, D.       View       Y      NaN
# ..          ...                           ...        ...     ...      ...
# 162         NaN                       LEX, A.       View       Y      NaN
# 164         NaN                       LEX, A.       View       Y      NaN
# 166         NaN  TASDIZEN, T. WHITAKER, R. T.       View       Y      NaN
# 168         NaN               THOMPSON, W. B.       View     NaN      NaN
# 170         NaN                     COHEN, E.       View       Y      NaN
# 171         NaN                STEVENS, K. S.        NaN       Y   $30.00
# 173         NaN                 WALKER, R. M.        NaN       Y   $30.00
# 175         NaN             NAZM BOJNORDI, M.        NaN       Y      NaN
# 177         NaN                    REGEHR, J.        NaN     NaN      NaN
# 178         NaN             GAILLARDON, P. J.        NaN     NaN  $155.00
# 180         NaN             GAILLARDON, P. J.        NaN     NaN      NaN
# 182         NaN                  PASCUCCI, V.       View     NaN      NaN
# 184         NaN                  STUTSMAN, R.       View     NaN      NaN
# 185         NaN                        JI, M.        NaN     NaN      NaN
# 187         NaN                    YUKSEL, C.        NaN     NaN      NaN
# 188         NaN        VENKATASUBRAMANIAN, S.        NaN     NaN      NaN
# 189         NaN       HERMANS, T. HERMANS, T.  View View     NaN      NaN
# 190         NaN                  BHASKARA, A.        NaN     NaN      NaN
# 191         NaN              HENDERSON, T. C.        NaN     NaN      NaN
# 192         NaN                    YUKSEL, C.        NaN     NaN      NaN
# 193         NaN                   EIDE, E. N.        NaN     NaN      NaN
# 194         NaN                    SUNDAR, H.       View     NaN      NaN
# 196         NaN                   DENNING, T.        NaN     NaN      NaN
# 197         NaN           BALASUBRAMONIAN, R.       View     NaN      NaN
# 199         NaN                     JOSHI, S.        NaN     NaN      NaN
# 201         NaN                   HERMANS, T.        NaN     NaN      NaN
# 203         NaN                   HALL, M. W.       View     NaN      NaN
# 205         NaN               PHILLIPS, B. W.        NaN     NaN      NaN
# 206         NaN                       LEX, A.        NaN     NaN      NaN
# 208         NaN           BALASUBRAMONIAN, R.        NaN     NaN      NaN
#
# [133 rows x 14 columns]

# %% [markdown]
# This looks better. But thinks like object oriented programming have many entries for each section. We'll filter to only contain lectures, seminars or special topic lectures.

# %%
classes = classes[(classes["Component"] == "Lecture") | (classes["Component"] == "Seminar") | (classes["Component"] == "Special Topics")]
classes
# Out:
#     Class # Subject   Cat. #  Sec.       Component      Units  \
# 0       NaN       CS   350.0   1.0         Lecture        0.0
# 4       NaN       CS  1030.0   1.0         Lecture        3.0
# 22      NaN       CS  1410.0   1.0         Lecture        4.0
# 31      NaN       CS  1410.0  30.0         Lecture        4.0
# 43      NaN       CS  1410.0  40.0         Lecture        4.0
# 55      NaN       CS  2100.0   1.0         Lecture        3.0
# 60      NaN       CS  2420.0   1.0         Lecture        4.0
# 68    10932       CS  3020.0   1.0         Seminar        1.0
# 69     6083       CS  3100.0   1.0         Lecture        3.0
# 70     9975       CS  3130.0   1.0         Lecture        3.0
# 72      NaN       CS  3500.0   1.0         Lecture        4.0
# 82      NaN       CS  3505.0   1.0         Lecture        3.0
# 89     1182       CS  3810.0   1.0         Lecture        4.0
# 91    16809       CS  3960.0   1.0  Special Topics        3.0
# 93     5822       CS  3991.0   1.0         Seminar        1.0
# 95    12552       CS  4000.0   1.0         Lecture        3.0
# 98    16799       CS  4150.0   1.0         Lecture        3.0
# 99    14197       CS  4300.0   1.0         Lecture        3.0
# 100     NaN       CS  4400.0   1.0         Lecture        4.0
# 105   16802       CS  4500.0   1.0         Lecture        3.0
# 106   17112       CS  4530.0   1.0         Lecture        3.0
# 107   17113       CS  4530.0   2.0         Lecture        3.0
# 108   13433       CS  4600.0   1.0         Lecture        3.0
# 111   16807       CS  4964.0   1.0  Special Topics        3.0
# 113   16758       CS  5150.0   1.0         Lecture        3.0
# 115    1183       CS  5310.0   1.0         Lecture        3.0
# 117   14733       CS  5340.0   1.0         Lecture        3.0
# 119   14739       CS  5350.0   1.0         Lecture        3.0
# 121   13520       CS  5490.0   1.0         Lecture        3.0
# 123   14743       CS  5510.0   1.0         Lecture        3.0
# ..      ...      ...     ...   ...             ...        ...
# 160   15858       CS  6530.0   2.0         Lecture        3.0
# 162    5496       CS  6630.0   1.0         Lecture        3.0
# 164   15859       CS  6630.0   2.0         Lecture        3.0
# 166    9223       CS  6640.0   1.0         Lecture        3.0
# 168   16796       CS  6650.0   1.0         Lecture        3.0
# 170   16993       CS  6670.0   1.0         Lecture        3.0
# 171    5088       CS  6710.0   1.0         Lecture        4.0
# 173   18444       CS  6720.0   1.0         Lecture        3.0
# 175   16482       CS  6810.0   1.0         Lecture        3.0
# 177   17110       CS  6960.0   1.0  Special Topics        3.0
# 178     NaN       CS  6961.0   1.0  Special Topics        3.0
# 182   13635       CS  6962.0   1.0  Special Topics        3.0
# 184   14742       CS  6963.0   1.0  Special Topics        3.0
# 185   14045       CS  6964.0   1.0  Special Topics        3.0
# 187   16805       CS  6967.0   1.0  Special Topics        3.0
# 188   16806       CS  6968.0   1.0  Special Topics        3.0
# 189    6456       CS  7930.0   1.0         Seminar  1.0 - 3.0
# 190   11348       CS  7931.0   1.0         Seminar  1.0 - 3.0
# 191    6888       CS  7932.0   1.0         Seminar  1.0 - 3.0
# 192    9231       CS  7933.0   2.0         Seminar        1.0
# 193    6889       CS  7934.0   1.0         Seminar  1.0 - 3.0
# 194   16223       CS  7935.0   1.0         Seminar  1.0 - 3.0
# 196   15505       CS  7936.0   1.0         Seminar        1.0
# 197   13134       CS  7937.0   1.0         Seminar  1.0 - 3.0
# 199    8960       CS  7938.0   1.0         Seminar        1.0
# 201    7224       CS  7939.0   1.0         Seminar        1.0
# 203   16174       CS  7940.0   1.0         Seminar  1.0 - 3.0
# 205   13528       CS  7941.0   1.0         Seminar  1.0 - 3.0
# 206    9046       CS  7942.0   1.0         Seminar  1.0 - 3.0
# 208   18133       CS  7960.0   1.0  Special Topics        3.0
#
#                              Title  \
# 0                Software Practice
# 4                Foundations of CS
# 22            Object-Oriented Prog
# 31            Object-Oriented Prog
# 43            Object-Oriented Prog
# 55             Discrete Structures
# 60         Intro Alg & Data Struct
# 68                  Research Forum
# 69           Models Of Computation
# 70                  Eng Prob Stats
# 72               Software Practice
# 82            Software Practice II
# 89           Computer Organization
# 91            Parallel Programming
# 93               CE Junior Seminar
# 95          Senior Capstone Design
# 98                      Algorithms
# 99         Artificial Intelligence
# 100               Computer Systems
# 105        Senior Capstone Project
# 106         Mobile App Programming
# 107         Mobile App Programming
# 108              Computer Graphics
# 111                  Math for Data
# 113            Advanced Algorithms
# 115                       Robotics
# 117               Natural Language
# 119               Machine Learning
# 121               Network Security
# 123          Programming Languages
# ..                             ...
# 160               Database Systems
# 162                  Visualization
# 164                  Visualization
# 166               Image Processing
# 168        Perception for Graphics
# 170          Cptr-Aided Geom Des I
# 171            Digital VLSI Design
# 173               Analog IC Design
# 175          Computer Architecture
# 177             Advanced Compilers
# 178             VLSI Memory Design
# 182      Programming for Engineers
# 184            Distributed Systems
# 185               Caching Networks
# 187           Numerical Simulation
# 188                     Clustering
# 189                     Colloquium
# 190       Machine Learning Seminar
# 191  Img Motion Estmtn and Intprtn
# 192               Graphics Seminar
# 193       Computer Systems Seminar
# 194     Distributed Linear Algebra
# 196               Security Seminar
# 197                      Arch/VLSI
# 199         Image Analysis Seminar
# 201                       Robotics
# 203       Performance Optimization
# 205               Advanced Seminar
# 206          Visualization Seminar
# 208     Neuromorphic Architectures
#
#                             Days/Time & Session           Location  \
# 0                          TH / 02:00PM-03:20PM           WEB L104
# 4                          MW / 02:00PM-02:50PM           WEB L104
# 22                        MWF / 10:45AM-11:35AM           WEB L104
# 31                         MW / 08:05AM-09:25AM           WEB L105
# 43                         MW / 08:05AM-09:25AM           WEB L105
# 55                         TH / 12:25PM-01:45PM           WEB L101
# 60                         MW / 03:00PM-04:20PM           WEB L104
# 68                          F / 09:10AM-10:30AM           MEB 3147
# 69                         TH / 10:45AM-12:05PM           WEB L101
# 70                         TH / 03:40PM-05:00PM           WEB L101
# 72                         TH / 02:00PM-03:20PM           WEB L104
# 82                         TH / 02:00PM-03:20PM           WEB L103
# 89                         TH / 09:10AM-10:30AM           WEB L104
# 91                         TH / 09:10AM-10:30AM           WEB 1250
# 93                          T / 10:45AM-12:05PM           MEB 3147
# 95                        MWF / 10:45AM-11:35AM           WEB 2230
# 98                         MW / 03:00PM-04:20PM           WEB L101
# 99                         TH / 10:45AM-12:05PM           WEB 1250
# 100                        MW / 01:25PM-02:45PM           WEB L101
# 105                        TH / 03:40PM-05:00PM           WEB 2250
# 106                        MW / 03:00PM-04:20PM          M LI 1120
# 107                        MW / 04:35PM-05:55PM          M LI 1120
# 108                        MW / 11:50AM-01:10PM           WEB 1230
# 111                        TH / 12:25PM-01:45PM           MEB 3105
# 113                        TH / 10:45AM-12:05PM           WEB L105
# 115                       MWF / 02:00PM-02:50PM           WEB L103
# 117                        MW / 03:00PM-04:20PM           WEB 1250
# 119                        TH / 09:10AM-10:30AM           WEB L101
# 121                        MW / 01:25PM-02:45PM           WEB L102
# 123                        TH / 12:25PM-01:45PM           WEB 2250
# ..                                          ...                ...
# 160                        TH / 12:25PM-01:45PM           WEB 1250
# 162                        TH / 02:00PM-03:20PM           WEB L101
# 164                        TH / 02:00PM-03:20PM           WEB L101
# 166                        MW / 01:25PM-02:45PM           WEB 1230
# 168                        MW / 11:50AM-01:10PM           WEB L122
# 170                        MW / 11:50AM-01:10PM           WEB 2460
# 171                        TH / 05:15PM-06:35PM           WEB 2230
# 173                        TH / 03:40PM-05:00PM           MEB 2325
# 175                        TH / 09:10AM-10:30AM           WEB L102
# 177                        TH / 02:00PM-03:20PM           WEB L122
# 178                        WF / 11:50AM-01:10PM           MEB 1225
# 182                        MW / 03:00PM-04:20PM           WEB L105
# 184                        TH / 03:40PM-05:00PM           WEB L102
# 185                        TH / 09:10AM-10:30AM              TBA .
# 187                        TH / 02:00PM-03:20PM           MEB 3147
# 188                        TH / 12:25PM-01:45PM           MEB 2325
# 189  MWF / 09:40AM-11:35AM TH / 03:40PM-05:00PM  WEB 1230 MEB 3147
# 190                         W / 01:25PM-02:45PM           MEB 3147
# 191                                         TBA                TBA
# 192                         T / 12:00PM-02:00PM           MEB 3147
# 193                         F / 02:00PM-03:30PM           WEB 1460
# 194                         W / 09:10AM-10:30AM           MEB 3147
# 196                         W / 12:00PM-01:00PM           MEB 3515
# 197                                         TBA                TBA
# 199                         M / 12:00PM-01:00PM           WEB 3760
# 201                         H / 12:55PM-01:45PM           MEB 3147
# 203                         M / 11:50AM-01:10PM              TBA .
# 205                         W / 11:50AM-01:10PM           MEB 3147
# 206                         F / 12:00PM-01:00PM           WEB 3760
# 208                        TH / 02:00PM-03:20PM           MEB 1225
#
#     Class Attrs                         Instructor  Feed back Pre Req     Fees
# 0          AOCE                       KOPTA, D. M.        NaN     NaN      NaN
# 4           NaN                         PARKER, D.        NaN       Y      NaN
# 22          NaN                     JOHNSON, D. E.        NaN       Y      NaN
# 31          NaN                         PARKER, D.       View       Y      NaN
# 43          NaN                         PARKER, D.       View       Y      NaN
# 55          NaN                      RAKAMARIC, Z.       View       Y      NaN
# 60          NaN                       MEYER, M. D.       View       Y      NaN
# 68          NaN                  HOLLERBACH, J. M.        NaN       Y      NaN
# 69           QI                     ZACHARY, J. L.       View       Y      NaN
# 70           QI                    FLETCHER, P. T.       View       Y      NaN
# 72          NaN                       KOPTA, D. M.        NaN       Y      NaN
# 82          NaN                     JOHNSON, D. E.       View       Y      NaN
# 89           QI                      JENSEN, P. A.       View       Y      NaN
# 91          NaN             HALL, M. W. SUNDAR, H.        NaN       Y      NaN
# 93          NaN                    BRUNVAND, E. L.       View       Y      NaN
# 95          NaN  DE ST GERMAIN, H. J. KOPTA, D. M.       View       Y      NaN
# 98           QI                     ZACHARY, J. L.       View       Y      NaN
# 99          NaN                   HENDERSON, T. C.       View       Y      NaN
# 100          QI                          FLATT, M.        NaN       Y      NaN
# 105         NaN  DE ST GERMAIN, H. J. KOPTA, D. M.       View       Y      NaN
# 106         NaN                      STOKER, M. L.        NaN       Y      NaN
# 107        FLXU                      STOKER, M. L.        NaN       Y      NaN
# 108         NaN                          KAVAN, L.        NaN       Y      NaN
# 111         NaN                       PHILLIPS, J.        NaN       Y      NaN
# 113         NaN                       BHASKARA, A.        NaN       Y      NaN
# 115         NaN                  HOLLERBACH, J. M.       View       Y      NaN
# 117         NaN                      RILOFF, E. M.       View       Y      NaN
# 119         NaN                       SRIKUMAR, V.       View       Y      NaN
# 121         NaN                      KASERA, S. K.       View       Y      NaN
# 123         NaN                          FLATT, M.       View       Y      NaN
# ..          ...                                ...        ...     ...      ...
# 160         NaN                             LI, F.       View       Y      NaN
# 162         NaN                            LEX, A.       View       Y      NaN
# 164         NaN                            LEX, A.       View       Y      NaN
# 166         NaN       TASDIZEN, T. WHITAKER, R. T.       View       Y      NaN
# 168         NaN                    THOMPSON, W. B.       View     NaN      NaN
# 170         NaN                          COHEN, E.       View       Y      NaN
# 171         NaN                     STEVENS, K. S.        NaN       Y   $30.00
# 173         NaN                      WALKER, R. M.        NaN       Y   $30.00
# 175         NaN                  NAZM BOJNORDI, M.        NaN       Y      NaN
# 177         NaN                         REGEHR, J.        NaN     NaN      NaN
# 178         NaN                  GAILLARDON, P. J.        NaN     NaN  $155.00
# 182         NaN                       PASCUCCI, V.       View     NaN      NaN
# 184         NaN                       STUTSMAN, R.       View     NaN      NaN
# 185         NaN                             JI, M.        NaN     NaN      NaN
# 187         NaN                         YUKSEL, C.        NaN     NaN      NaN
# 188         NaN             VENKATASUBRAMANIAN, S.        NaN     NaN      NaN
# 189         NaN            HERMANS, T. HERMANS, T.  View View     NaN      NaN
# 190         NaN                       BHASKARA, A.        NaN     NaN      NaN
# 191         NaN                   HENDERSON, T. C.        NaN     NaN      NaN
# 192         NaN                         YUKSEL, C.        NaN     NaN      NaN
# 193         NaN                        EIDE, E. N.        NaN     NaN      NaN
# 194         NaN                         SUNDAR, H.       View     NaN      NaN
# 196         NaN                        DENNING, T.        NaN     NaN      NaN
# 197         NaN                BALASUBRAMONIAN, R.       View     NaN      NaN
# 199         NaN                          JOSHI, S.        NaN     NaN      NaN
# 201         NaN                        HERMANS, T.        NaN     NaN      NaN
# 203         NaN                        HALL, M. W.       View     NaN      NaN
# 205         NaN                    PHILLIPS, B. W.        NaN     NaN      NaN
# 206         NaN                            LEX, A.        NaN     NaN      NaN
# 208         NaN                BALASUBRAMONIAN, R.        NaN     NaN      NaN
#
# [79 rows x 14 columns]

# %% [markdown]
# So who's teaching the most Lectures/Seminars/Special Topic Courses this semester?

# %%
classes["Instructor"].value_counts().head()
# Out:
# LEX, A.              4
# BHASKARA, A.         4
# LI, F.               3
# SRIKUMAR, V.         3
# HOLLERBACH, J. M.    3
# Name: Instructor, dtype: int64

# %% [markdown]
# This dataset isn't completely clean yet. There are multiple versions of classes that are not aggregated, and classes that are co-taught aren't properly separted. So for a real analysis we'd have to do more cleanup work.
#
# #### Counting Enrollment
#
# But let's look at which classes have the most students. To do this, we have to go back a couple of steps, because panda's importer didn't preserve the URLs, and the enrollment numbers are hidden just behind the next website. Here's an example for the [data science lecture](https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/sections.html?subj=CS&catno=5963).
#
# Let's scrape the number of students from this website:

# %%
with urllib.request.urlopen("https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/sections.html?subj=CS&catno=5963") as response:
    class_student_html = response.read()
class_student_soup = BeautifulSoup(class_student_html, 'html.parser')
# we use pandas to read the table
student_ar = pd.read_html(str(class_student_soup))
student_ar
# Out:
# [   Class # Subject  Catalog #  Section           Title  Enrollment Cap  \
#  0    18213      CS       5963        1  Special Topics              30
#  1    18214      CS       5963        2  Special Topics              30
#
#     Currently Enrolled  Seats Available
#  0                  20               10
#  1                  20               10  ]

# %% [markdown]
# The dataframe is wrapped in an array, we can get the DF out of it:

# %%
student_df = student_ar[0]
student_df
# Out:
#    Class # Subject  Catalog #  Section           Title  Enrollment Cap  \
# 0    18213      CS       5963        1  Special Topics              30
# 1    18214      CS       5963        2  Special Topics              30
#
#    Currently Enrolled  Seats Available
# 0                  20               10
# 1                  20               10

# %% [markdown]
# Now, we can retreive the student number:

# %%
students = student_df["Currently Enrolled"][0]
students
# Out:
# 20

# %% [markdown]
# Let's pack this all up in a function that takes the URL and returns the number:

# %%
def scrape_students(url):
    """
    Retreive the number of students from the table on the website specified in the URL
    """
    with urllib.request.urlopen(url) as response:
        class_student_html = response.read()
    class_student_soup = BeautifulSoup(class_student_html, 'html.parser')
    # we use pandas to read the table
    student_df = pd.read_html(str(class_student_soup))[0]
    students = student_df["Currently Enrolled"][0]
    return students

# %%
# test it with the datascience lecture
scrape_students("https://student.apps.utah.edu/uofu/stu/ClassSchedules/main/1168/sections.html?subj=CS&catno=5963")
# Out:
# 20

# %% [markdown]
# Now we still have to extract the URL to pass into this function and the other attributes we care about from the website. Here we'll create a tailored solution to the website - this is of course brittle and will break if the website changes (the DOM of a website isn't supposed to be a stable API). But it's the best we can do.
#
# We'll create a matrix that we'll use to initialize a dataframe. Remember that we've extracted the table into classTable already.

# %%
print(classTable)
# Out:
# <table class="table table-bordered table-striped main-table" id="classDetailsTable">
# <thead><tr>
# <th class="nowrap">Class #</th>
# <th>Subject <span class="glyphs"></span></th>
# <th class="nowrap">Cat. #</th>
# <th>Sec.</th>
# <th>Component</th>
# <th>Units</th>
# <th>Title</th>
# <th class="nowrap">Days/Time &amp; Session</th>
# <th>Location</th>
# <th><a href="#">Class Attrs</a></th>
# <th>Instructor</th>
# <th><a href="#">Feed back</a></th>
# <th>Pre Req</th>
# <th>Fees</th>
# </tr>
# </thead>
# <tr class="even">
# <td><a name="18857"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=350&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=350">350</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  0.0</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?type=AOCE">AOCE</a>
# </p>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0297211/teaching/index.hml" target="_blank">KOPTA, D. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Section 8 belongs to this lecture. Student will automatically be registered for this lecture when registering for 008 discussion section. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 3500 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="18859"></a><span>18859</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=350&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=350">350</a>
# </td>
# <td>008</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?type=AOCE">AOCE</a>
# </p>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0297211/teaching/index.hml" target="_blank">KOPTA, D. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td><span>$605.00</span></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Section 1 belongs to this discussion. Student will automatically be registered for this lecture when registering for this section. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 3500 008</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="9894"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~parker/1030_F16.html">Foundations of CS</a>
# </td>
# <td class="nowrap">
# <p><span>MW</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 8 belong to this lecture. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. Some students may waive CS 1030 and go directly into CS 1410. To determine whether you should begin your programming coursework with CS 1030 or CS 1410, go to www.cs.utah.edu/~parker/instructions to take the proficiency test. This is REQUIRED prior to registration. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="9896"></a><span>9896</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 002</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="9897"></a><span>9897</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 003</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="9898"></a><span>9898</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>05:15PM-06:05PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 004</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="9899"></a><span>9899</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>04:10PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 005</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="10967"></a><span>10967</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 006</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="12992"></a><span>12992</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>007</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 007</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="14035"></a><span>14035</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1030&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1030">1030</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Foundations of CS</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>EAE 1030 008</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="5100"></a><span>5100</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1040&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1040">1040</a>
# </td>
# <td>090</td>
# <td>Laboratory</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Creating Web Content</span>
# </td>
# <td class="nowrap">
# <p>TBA<br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?type=ONLN">ONLN</a>
# </p>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7963" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td><span>$60.00</span></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This is an online course, which does not meet in-class. For additional information, please visit <a href="http://uonline.utah.edu" target="_blank">http://uonline.utah.edu</a> or call 585-5959. </span>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="1177"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="https://www.cs.utah.edu/~dejohnso/CS1410_F16.html">Object-Oriented Prog</a>
# </td>
# <td class="nowrap">
# <p><span>MWF</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 7 belong to this lecture. This section is intended for Computer Science pre-majors only. Computer Engineering and Electrical Engineering majors and pre-majors should register in sections 030 or 040, respectively. This course requires registration for a lab section. Students will be automatically registered for this lecture section when registering for the pertinent lab section. In order to register for this course, students must have completed or waived CS 1030. Go to www.cs.utah.edu/~parker/instructions for the proficiency test required to waive CS 1030. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="1698"></a><span>1698</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="1699"></a><span>1699</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="1700"></a><span>1700</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="1701"></a><span>1701</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="1702"></a><span>1702</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>02:00PM-02:50PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="11038"></a><span>11038</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>007</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15519"></a><span>15519</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>008</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>03:05PM-03:55PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0061533/teaching/index.hml" target="_blank">JOHNSON, D. E.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="11020"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>030</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~parker/1410_30_F16.html">Object-Oriented Prog</a>
# </td>
# <td class="nowrap">
# <p><span>MW</span> / <span>08:05AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L105</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 31-35 belong to this lecture. This section is an embedded systems version of CS 1410, required by Computer Engineering majors and pre-majors. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. This section is an embedded systems version of CS 1410. In order to register, students must have completed or waived CS 1030. Go to www.cs.utah.edu/~parker/instructions for the proficiency test required to waive CS 1030. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 040</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="11021"></a><span>11021</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>031</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 041</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="11022"></a><span>11022</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>032</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 042</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="11023"></a><span>11023</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>033</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 043</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="11564"></a><span>11564</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>034</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 044</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13211"></a><span>13211</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>035</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 045</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="13629"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>040</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~parker/1410_30_F16.html">Object-Oriented Prog</a>
# </td>
# <td class="nowrap">
# <p><span>MW</span> / <span>08:05AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L105</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 041 - 045 belong to this lecture. This section is an embedded systems version of CS 1410, and is restricted to Electrical Engineering majors and pre-majors. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. The CS 1030 prerequisite is waived for EE students registering for this section. Students must fill out a web form at <a href="http://www.ece.utah.edu/course_perms" target="_blank">http://www.ece.utah.edu/course_perms</a> to get a permission code. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 030</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13630"></a><span>13630</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>041</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 031</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="13631"></a><span>13631</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>042</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 032</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13632"></a><span>13632</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>043</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 033</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="13633"></a><span>13633</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>044</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 034</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13637"></a><span>13637</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=1410&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=1410">1410</a>
# </td>
# <td>045</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Object-Oriented Prog</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L124</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0471866/teaching/index.hml" target="_blank">PARKER, D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7968" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS 1410 035</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="4794"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0849246/teaching/index.hml" target="_blank">RAKAMARIC, Z.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1148&amp;class_nbr=5015" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 4 belong to this lecture. This course requires registration for a discussion section. Students will be automatically registered for this lecture section when registering for the discussion section. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="6453"></a><span>6453</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>002</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L112</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0849246/teaching/index.hml" target="_blank">RAKAMARIC, Z.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1148&amp;class_nbr=5015" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6454"></a><span>6454</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>003</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L122</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0849246/teaching/index.hml" target="_blank">RAKAMARIC, Z.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1148&amp;class_nbr=5015" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="6455"></a><span>6455</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2100">2100</a>
# </td>
# <td>004</td>
# <td>Discussion</td>
# <td>--</td>
# <td class="title-width">
# <span>Discrete Structures</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L122</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0849246/teaching/index.hml" target="_blank">RAKAMARIC, Z.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1148&amp;class_nbr=5015" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="13881"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>MW</span> / <span>03:00PM-04:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2-5 belong to this section. This course requires registration for a lab and/or discussion section. Students will be automatically registered for this lecture section when registering for the pertinent lab and/or discussion section. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13882"></a><span>13882</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>002</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>09:40AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="13883"></a><span>13883</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>003</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>10:45AM-11:35AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="13884"></a><span>13884</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>004</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>11:50AM-12:40PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="13885"></a><span>13885</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>005</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="15897"></a><span>15897</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2420&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2420">2420</a>
# </td>
# <td>006</td>
# <td>Laboratory</td>
# <td>--</td>
# <td class="title-width">
# <span>Intro Alg &amp; Data Struct</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>08:35AM-09:25AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0341935/teaching/index.hml" target="_blank">MEYER, M. D.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=7980" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="9973"></a><span>9973</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=2963&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=2963">2963</a>
# </td>
# <td>001</td>
# <td>Lab/ Discussion</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>LPI Level 1</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>06:00PM-09:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=ANNEX" target="_blank">ANNEX 2214</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?type=FLXU">FLXU</a>
# </p>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0708330/teaching/index.hml" target="_blank">TOPONCE, A. S.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td><span>$1,500.00</span></td>
# </tr>
# <tr class="even">
# <td><a name="10932"></a><span>10932</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3020&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3020">3020</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <a href="http://www.coe.utah.edu/~cs3020/">Research Forum</a>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>09:10AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0029780/teaching/index.hml" target="_blank">HOLLERBACH, J. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6083"></a><span>6083</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3100&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3100">3100</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Models Of Computation</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>10:45AM-12:05PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=QI">QI</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0028988/teaching/index.hml" target="_blank">ZACHARY, J. L.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=6336" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="9975"></a><span>9975</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3130&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3130">3130</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Eng Prob Stats</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>03:40PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L101</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=QI">QI</a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0467708/teaching/index.hml" target="_blank">FLETCHER, P. T.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=10685" target="_blank">View</a>
# </p>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 3530 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="1181"></a></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=3500&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=3500">3500</a>
# </td>
# <td>001</td>
# <td>Lecture</td>
# <td>  4.0</td>
# <td class="title-width">
# <span>Software Practice</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB L104</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0297211/teaching/index.hml" target="_blank">KOPTA, D. M.</a>
# </p>
# </td>
# <td>
# </td>
# <td>Y</td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>Sections 2 - 8 belongs to this lecture. This course requires registration for a discussion section. Students will be automatically registered for this lecture section when registering for the pertinent discussion section. </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>CS  350 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="1722"></a><span>1722</span></td>
# <td>
# ...
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=16764" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="14045"></a><span>14045</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6964&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6964">6964</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Caching Networks</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>09:10AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6007330/teaching/index.hml" target="_blank">JI, M.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 2102 (Conference room) </span>
# </p>
# <hr/>
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 6960 007</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="16805"></a><span>16805</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6967&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6967">6967</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="http://graphics.cs.utah.edu/courses/cs6967/fall2016/">Numerical Simulation</a>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0852752/teaching/index.hml" target="_blank">YUKSEL, C.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="16806"></a><span>16806</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=6968&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=6968">6968</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <span>Clustering</span>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>12:25PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 2325</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0548623/teaching/index.hml" target="_blank">VENKATASUBRAMANIAN, S.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6456"></a><span>6456</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7930&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7930">7930</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Colloquium</span>
# </td>
# <td class="nowrap">
# <p><span>MWF</span> / <span>09:40AM-11:35AM</span> <br/>
# </p>
# <p><span>TH</span> / <span>03:40PM-05:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 1230</a>
# </p>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6002596/teaching/index.hml" target="_blank">HERMANS, T.</a>
# </p>
# <p>
# <a href="http://faculty.utah.edu/u6002596/teaching/index.hml" target="_blank">HERMANS, T.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=8027" target="_blank">View</a>
# </p>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=8027" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="11348"></a><span>11348</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7931&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7931">7931</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Machine Learning Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>01:25PM-02:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6001941/teaching/index.hml" target="_blank">BHASKARA, A.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6888"></a><span>6888</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7932&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7932">7932</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~tch/CS7932F2016">Img Motion Estmtn and Intprtn</a>
# </td>
# <td class="nowrap">
# <p>TBA<br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0030110/teaching/index.hml" target="_blank">HENDERSON, T. C.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="9231"></a><span>9231</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7933&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7933">7933</a>
# </td>
# <td>002</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Graphics Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>T</span> / <span>12:00PM-02:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0852752/teaching/index.hml" target="_blank">YUKSEL, C.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="6889"></a><span>6889</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7934&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7934">7934</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <a href="http://www.eng.utah.edu/~csl-sem/">Computer Systems Seminar</a>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>02:00PM-03:30PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 1460</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0031750/teaching/index.hml" target="_blank">EIDE, E. N.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="16223"></a><span>16223</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7935&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7935">7935</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Distributed Linear Algebra</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>09:10AM-10:30AM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0978964/teaching/index.hml" target="_blank">SUNDAR, H.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=18537" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This seminar will focus on distributed linear algebra algorithms. Attendees will read and discuss papers on core large-scale Linear Algebra algorithms such as dense matrix representations, matrix factorizations, singular value decomposition etc. Attendees will typically discuss one paper each week. </span>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="15505"></a><span>15505</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7936&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7936">7936</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Security Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3515</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0982243/teaching/index.hml" target="_blank">DENNING, T.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><a name="13134"></a><span>13134</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7937&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7937">7937</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Arch/VLSI</span>
# </td>
# <td class="nowrap">
# <p>TBA<br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0415400/teaching/index.hml" target="_blank">BALASUBRAMONIAN, R.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1164&amp;class_nbr=10896" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 2180 </span>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="8960"></a><span>8960</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7938&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7938">7938</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Image Analysis Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>M</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 3760</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0492366/teaching/index.hml" target="_blank">JOSHI, S.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>BIOEN 6810 001</li>
# <li>ECE 6960 006</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="7224"></a><span>7224</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7939&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7939">7939</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0</td>
# <td class="title-width">
# <span>Robotics</span>
# </td>
# <td class="nowrap">
# <p><span>H</span> / <span>12:55PM-01:45PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6002596/teaching/index.hml" target="_blank">HERMANS, T.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ME EN 7960 001</li>
# </ul>
# </p>
# </td>
# </tr>
# <tr class="odd">
# <td><a name="16174"></a><span>16174</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7940&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7940">7940</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Performance Optimization</span>
# </td>
# <td class="nowrap">
# <p><span>M</span> / <span>11:50AM-01:10PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <span>TBA .</span>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0636183/teaching/index.hml" target="_blank">HALL, M. W.</a>
# </p>
# </td>
# <td>
# <p>
# <a href="/uofu/stu/SCFStudentResults/publicReports?cmd=showReport&amp;strm=1158&amp;class_nbr=18482" target="_blank">View</a>
# </p>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class meets in MEB 3445. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="13528"></a><span>13528</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7941&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7941">7941</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Advanced Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>W</span> / <span>11:50AM-01:10PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 3147</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0731785/teaching/index.hml" target="_blank">PHILLIPS, B. W.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><a name="9046"></a><span>9046</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7942&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7942">7942</a>
# </td>
# <td>001</td>
# <td>Seminar</td>
# <td>  1.0 -   3.0</td>
# <td class="title-width">
# <span>Visualization Seminar</span>
# </td>
# <td class="nowrap">
# <p><span>F</span> / <span>12:00PM-01:00PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=WEB" target="_blank">WEB 3760</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u6002873/teaching/index.hml" target="_blank">LEX, A.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd notes">
# <td colspan="15">
# <p>
# <span>This class will meet in WEB 3780. </span>
# </p>
# </td>
# </tr>
# <tr class="even">
# <td><a name="18133"></a><span>18133</span></td>
# <td>
# <a href="https://gate.acs.utah.edu/psc/coursepr/EMPLOYEE/HRMS/c/SA_LEARNER_SERVICES.UU_CTLG_SEARCH.GBL?catalognbr=7960&amp;subject=CS&amp;term=1168">CS</a>
# </td>
# <td>
# <a href="sections.html?subj=CS&amp;catno=7960">7960</a>
# </td>
# <td>001</td>
# <td>Special Topics</td>
# <td>  3.0</td>
# <td class="title-width">
# <a href="http://www.cs.utah.edu/~rajeev/cs7960">Neuromorphic Architectures</a>
# </td>
# <td class="nowrap">
# <p><span>TH</span> / <span>02:00PM-03:20PM</span> <br/>
# </p>
# </td>
# <td>
# <p>
# <a href="http://map.utah.edu/index.html?code=MEB" target="_blank">MEB 1225</a>
# </p>
# </td>
# <td>
# <p>
# <a href="class_list.html?req=+"> </a>
# </p>
# </td>
# <td>
# <p>
# <a href="http://faculty.utah.edu/u0415400/teaching/index.hml" target="_blank">BALASUBRAMONIAN, R.</a>
# </p>
# </td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even notes">
# <td colspan="15">
# <p>
# <em> Meets With</em>
# <ul>
# <li>ECE 7960 001</li>
# </ul>
# </p>
# </td>
# </tr>
# </table>

# %% [markdown]
# As usual, that's not very readable. Here's the inspector version:
#
# ![Table](table.png)
#
# We see that the rows without content have two properties: they have a class attribute `notes` and the have only one nested td - in cointrast to the rows that contain data. We could use either of these properties to pick the right dataset.

# %%
header = ["Subject", "Number", "Section", "Type", "Title", "Instructor", "Students" ]
matrix = []

for row in classTable.find_all("tr"):
    # extracting the tds
    tds = row.find_all("td")
   
    # The columsn in the table are 
    # Class; Subject; Cat. #; Sec.; Component; Units; Title; Days/Time & Session; 
    # Location; Class Attrs; Instructor; Feed back; Pre Req; Fees
    # we want the data defined in the header
    if (len(tds) > 1):
        # print(tds)
        record = []
        # here we manually extract the field we want. Ugly. But it works. 
        record.append(tds[1].text.strip()) # subject
        record.append(tds[2].text.strip()) # cat #
        record.append(tds[3].text.strip()) # Section
        record.append(tds[4].text.strip()) # Component/Type
        record.append(tds[6].text.strip()) # Title
        record.append(tds[10].text.strip()) # Instructor
        # reconstruct the URL:
        student_url = url+tds[2].find("a").get("href")
        # here we call scrape_students, which extracts the number of students  
        students = scrape_students(student_url)
        record.append(students)
        # print(record)
        matrix.append(record)

# %% [markdown]
# Let's look at the first elements in the matrix:

# %%
matrix[0:4]
# Out:
# [['CS', '350', '001', 'Lecture', 'Software Practice', 'KOPTA, D. M.', 0],
#  ['CS', '350', '008', 'Discussion', 'Software Practice', 'KOPTA, D. M.', 0],
#  ['CS', '1030', '001', 'Lecture', 'Foundations of CS', 'PARKER, D.', 131],
#  ['CS', '1030', '002', 'Laboratory', 'Foundations of CS', 'PARKER, D.', 131]]

# %% [markdown]
# That looks good! Let's put this into a dataframe:

# %%
classes = pd.DataFrame(matrix, columns=header)

# %% [markdown]
# Back to the cleaup we did earlier:

# %%
classes = classes[(classes["Type"] == "Lecture") | (classes["Type"] == "Seminar") | (classes["Type"] == "Special Topics")]
classes.head()
# Out:
#    Subject Number Section     Type                 Title      Instructor  \
# 0       CS    350     001  Lecture     Software Practice    KOPTA, D. M.
# 2       CS   1030     001  Lecture     Foundations of CS      PARKER, D.
# 11      CS   1410     001  Lecture  Object-Oriented Prog  JOHNSON, D. E.
# 19      CS   1410     030  Lecture  Object-Oriented Prog      PARKER, D.
# 25      CS   1410     040  Lecture  Object-Oriented Prog      PARKER, D.
#
#     Students
# 0          0
# 2        131
# 11       218
# 19       218
# 25       218

# %% [markdown]
# When we have sections, students are usually enrolled in the main lecutre "001" and in sections ("002", "003", etc.) Let's count only the primary sections. This isn't valid for all situations, but fixing that problem autmomatically is hard.

# %%
mask = classes["Section"] == "001"
classes = classes[mask]
classes.head()
# Out:
#    Subject Number Section     Type                    Title      Instructor  \
# 0       CS    350     001  Lecture        Software Practice    KOPTA, D. M.
# 2       CS   1030     001  Lecture        Foundations of CS      PARKER, D.
# 11      CS   1410     001  Lecture     Object-Oriented Prog  JOHNSON, D. E.
# 31      CS   2100     001  Lecture      Discrete Structures   RAKAMARIC, Z.
# 35      CS   2420     001  Lecture  Intro Alg & Data Struct    MEYER, M. D.
#
#     Students
# 0          0
# 2        131
# 11       218
# 31       160
# 35       131

# %% [markdown]
# Now let's look at which are the largest classes:

# %%
classes = classes.sort_values("Students", ascending=False)
classes = classes.reset_index(drop=True)
classes.head()
# Out:
#   Subject Number Section     Type                  Title      Instructor  \
# 0      CS   1410     001  Lecture   Object-Oriented Prog  JOHNSON, D. E.
# 1      CS   3500     001  Lecture      Software Practice    KOPTA, D. M.
# 2      CS   2100     001  Lecture    Discrete Structures   RAKAMARIC, Z.
# 3      CS   3810     001  Lecture  Computer Organization   JENSEN, P. A.
# 4      CS   1030     001  Lecture      Foundations of CS      PARKER, D.
#
#    Students
# 0       218
# 1       167
# 2       160
# 3       138
# 4       131

# %% [markdown]
# Now, we want to answer the question **at which level are the most students enrolled in CS?** Levels are the leading digit of the course number. Let's create a new column level and add it to the dataframe:

# %%
classes["level"] = classes["Number"].map(lambda x: (str(x)[0]))
classes
# Out:
#    Subject Number Section            Type                          Title  \
# 0       CS   1410     001         Lecture           Object-Oriented Prog
# 1       CS   3500     001         Lecture              Software Practice
# 2       CS   2100     001         Lecture            Discrete Structures
# 3       CS   3810     001         Lecture          Computer Organization
# 4       CS   1030     001         Lecture              Foundations of CS
# 5       CS   2420     001         Lecture        Intro Alg & Data Struct
# 6       CS   4400     001         Lecture               Computer Systems
# 7       CS   3100     001         Lecture          Models Of Computation
# 8       CS   3130     001         Lecture                 Eng Prob Stats
# 9       CS   4150     001         Lecture                     Algorithms
# 10      CS   6350     001         Lecture               Machine Learning
# 11      CS   6150     001         Lecture            Advanced Algorithms
# 12      CS   3505     001         Lecture           Software Practice II
# 13      CS   4000     001         Lecture         Senior Capstone Design
# 14      CS   4300     001         Lecture        Artificial Intelligence
# 15      CS   5510     001         Lecture          Programming Languages
# 16      CS   6630     001         Lecture                  Visualization
# 17      CS   5540     001         Lecture        Human/Computer Interact
# 18      CS   6340     001         Lecture               Natural Language
# 19      CS   6530     001         Lecture               Database Systems
# 20      CS   6810     001         Lecture          Computer Architecture
# 21      CS   4964     001  Special Topics                  Math for Data
# 22      CS   5350     001         Lecture               Machine Learning
# 23      CS   4600     001         Lecture              Computer Graphics
# 24      CS   6640     001         Lecture               Image Processing
# 25      CS   6963     001  Special Topics            Distributed Systems
# 26      CS   5340     001         Lecture               Natural Language
# 27      CS   4530     001         Lecture         Mobile App Programming
# 28      CS   4500     001         Lecture        Senior Capstone Project
# 29      CS   6490     001         Lecture               Network Security
# ..     ...    ...     ...             ...                            ...
# 41      CS   6310     001         Lecture                       Robotics
# 42      CS   6370     001         Lecture                Motion Planning
# 43      CS   3991     001         Seminar              CE Junior Seminar
# 44      CS   6967     001  Special Topics           Numerical Simulation
# 45      CS   7931     001         Seminar       Machine Learning Seminar
# 46      CS   7940     001         Seminar       Performance Optimization
# 47      CS   5310     001         Lecture                       Robotics
# 48      CS   6670     001         Lecture          Cptr-Aided Geom Des I
# 49      CS   5630     001         Lecture                  Visualization
# 50      CS   7930     001         Seminar                     Colloquium
# 51      CS   6210     001         Lecture            Adv Sci Computing I
# 52      CS   7942     001         Seminar          Visualization Seminar
# 53      CS   5650     001         Lecture        Perception for Graphics
# 54      CS   5962     001  Special Topics      Programming for Engineers
# 55      CS   5150     001         Lecture            Advanced Algorithms
# 56      CS   7935     001         Seminar     Distributed Linear Algebra
# 57      CS   7938     001         Seminar         Image Analysis Seminar
# 58      CS   7939     001         Seminar                       Robotics
# 59      CS   6710     001         Lecture            Digital VLSI Design
# 60      CS   7934     001         Seminar       Computer Systems Seminar
# 61      CS   7936     001         Seminar               Security Seminar
# 62      CS   7932     001         Seminar  Img Motion Estmtn and Intprtn
# 63      CS   5710     001         Lecture            Digital VLSI Design
# 64      CS   7937     001         Seminar                      Arch/VLSI
# 65      CS   6961     001  Special Topics             VLSI Memory Design
# 66      CS   6020     001         Lecture          Early-Career Research
# 67      CS   6964     001  Special Topics               Caching Networks
# 68      CS   6720     001         Lecture               Analog IC Design
# 69      CS   5720     001         Lecture               Analog IC Design
# 70      CS    350     001         Lecture              Software Practice
#
#                                 Instructor  Students level
# 0                           JOHNSON, D. E.       218     1
# 1                             KOPTA, D. M.       167     3
# 2                            RAKAMARIC, Z.       160     2
# 3                            JENSEN, P. A.       138     3
# 4                               PARKER, D.       131     1
# 5                             MEYER, M. D.       131     2
# 6                                FLATT, M.       122     4
# 7                           ZACHARY, J. L.       117     3
# 8                          FLETCHER, P. T.       102     3
# 9                           ZACHARY, J. L.        95     4
# 10                            SRIKUMAR, V.        84     6
# 11                            BHASKARA, A.        84     6
# 12                          JOHNSON, D. E.        84     3
# 13  DE ST GERMAIN, H. J.\n\n\nKOPTA, D. M.        71     4
# 14                        HENDERSON, T. C.        59     4
# 15                               FLATT, M.        59     5
# 16                                 LEX, A.        52     6
# 17                               WIESE, J.        49     5
# 18                           RILOFF, E. M.        44     6
# 19                                  LI, F.        38     6
# 20                       NAZM BOJNORDI, M.        38     6
# 21                            PHILLIPS, J.        36     4
# 22                            SRIKUMAR, V.        35     5
# 23                               KAVAN, L.        35     4
# 24       TASDIZEN, T.\n\n\nWHITAKER, R. T.        34     6
# 25                            STUTSMAN, R.        30     6
# 26                           RILOFF, E. M.        29     5
# 27                           STOKER, M. L.        26     4
# 28  DE ST GERMAIN, H. J.\n\n\nKOPTA, D. M.        22     4
# 29                           KASERA, S. K.        22     6
# ..                                     ...       ...   ...
# 41                       HOLLERBACH, J. M.        11     6
# 42                             HERMANS, T.        11     6
# 43                         BRUNVAND, E. L.        11     3
# 44                              YUKSEL, C.        10     6
# 45                            BHASKARA, A.        10     7
# 46                             HALL, M. W.         9     7
# 47                       HOLLERBACH, J. M.         9     5
# 48                               COHEN, E.         8     6
# 49                                 LEX, A.         8     5
# 50            HERMANS, T.\n\n\nHERMANS, T.         7     7
# 51                         PHILLIPS, B. W.         7     6
# 52                                 LEX, A.         6     7
# 53                         THOMPSON, W. B.         5     5
# 54                            PASCUCCI, V.         5     5
# 55                            BHASKARA, A.         5     5
# 56                              SUNDAR, H.         4     7
# 57                               JOSHI, S.         4     7
# 58                             HERMANS, T.         4     7
# 59                          STEVENS, K. S.         3     6
# 60                             EIDE, E. N.         3     7
# 61                             DENNING, T.         3     7
# 62                        HENDERSON, T. C.         2     7
# 63                          STEVENS, K. S.         2     5
# 64                     BALASUBRAMONIAN, R.         2     7
# 65                       GAILLARDON, P. J.         2     6
# 66                                  LI, F.         0     6
# 67                                  JI, M.         0     6
# 68                           WALKER, R. M.         0     6
# 69                           WALKER, R. M.         0     5
# 70                            KOPTA, D. M.         0     3
#
# [71 rows x 8 columns]

# %% [markdown]
# We can calculate the answer with groupby:

# %%
import numpy as np
student_stats = classes.groupby("level").aggregate([np.sum, np.mean, np.std])
student_stats
# Out:
#       Students
#            sum        mean        std
# level
# 1          349  174.500000  61.518290
# 2          291  145.500000  20.506097
# 3          649   72.111111  63.117835
# 4          466   58.250000  35.792058
# 5          238   18.307692  19.058614
# 6          553   23.041667  23.811724
# 7           83    6.384615   4.500712

# %% [markdown]
# Let's visualize this with box plots:

# %%
# %matplotlib inline
from ggplot import *

ggplot(classes, aes(x='level', y="Students")) + geom_boxplot()
# Out:
# <ggplot: (294514233)>

# %% [markdown]
# And plot a bar chart for the number of students in the class:

# %%
sum_students = student_stats["Students"]
sum_students = sum_students.reset_index()

# %%
ggplot(sum_students, aes(x='level', weight="sum")) + geom_bar()
# Out:
# <ggplot: (-9223372036560261530)>

# %% [markdown]
# We can see that the most students are in the 3000 level and 6000 level classes.
